# %%
import sys,os
sys.path.append("../")

import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
from IPython.display import HTML
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# # Example of Change Object Groups.
#
# This notebook aims to present few example of `Change Object` Groups created by our algorithm on the article of `John Logie Baird`.
#
#
#  `Change Object:` consists of gaps of inserted and deleted string tokens which were either inserted or removed at contiguous positions. These gaps come between two revisions of an article.
#
#
# These `Change Object` groups were created by clustering `Change Vectors` created from neighbour tokens equal to `context_length`. Clustering is done using DBSCAN which has two parameters `eps` and `min_sampels`. We evaluate the clusters using V-Measure analysis on human annotated data created to mark the tokens which were about nationality of John Logie Baird.
#
# In order to identify the example of change object clusters which capture the nationality of *John Logie Baird* we use V-measure analysis to show the example of groups. As clusters are done using left and neighbour token Vectors we also show the left and neighbour context tokens along with gap of inserted and deleted tokens.
#
# **Example of good and bad clusters**
#
# A good example is one which has almost similar tokens in left and right context. As the tokens in context start getting of different kind groups would not be about same gap.

# %% [markdown]
# ### Reading the change object and human annotations

# %%
article_name = "John_Logie_Baird"
evaluation_dir =  "../data/evaluation/"

cluster_file_name = f"{article_name}_clusters.h5"
cluster_file_path = os.path.join(evaluation_dir, cluster_file_name)

evaluation_file_name = f"{article_name}.csv"
evaluation_file_path = os.path.join(evaluation_dir, evaluation_file_name)
   
dbscan_results = pd.read_hdf(cluster_file_path, "clusters")
evaluation_df = pd.read_csv(evaluation_file_path,
                            index_col=["context", "eps","min_samples"])


file_name = article_name + "_FULL.csv"
annotation_dir = "../data/annotation/"
full_file_path = os.path.join(annotation_dir, file_name)
annotation_df = pd.read_csv(full_file_path)
annotation_df = annotation_df[["revid_ctxt", "token_id",
                               "rev_id", "nationality", "birth_place", "Bulk" ]]

# %% [markdown]
# ## Example of  best and worst clusters

# %%
pd.set_option('display.max_rows', 860)

pd.set_option("display.max_colwidth",1200)

# %% [markdown]
# #### Evaluating Homogenity of  clusters
# Clusters with smaller value of context_length gives more homogenious clusters. In others words as we increase context value more noise start getting clustered.

# %%
evaluation_df.reset_index().set_index([ "context","eps",  "min_samples", ])\
    ["change_object_homegenity"].sort_values().iloc[-10:]
# Out:
# context  eps   min_samples
# 4        1.50  2              0.755881
# 2        2.25  2              0.758501
#          2.00  2              0.758574
#          0.50  2              0.759280
#          0.25  2              0.759280
#          0.75  2              0.759321
#          1.00  2              0.759341
#          1.25  2              0.759383
#          1.50  2              0.759435
#          1.75  2              0.759571
# Name: change_object_homegenity, dtype: float64

# %% [markdown]
# ### Best homogenity

# %% [markdown]
# We can see that this cluster has same neighbourhood being changed multiple times.
# Context_length = 2 is one of the reason both left and right context has the same token.

# %% [markdown]
# Parameters of the algorithm
# `Context_length = 2, eps = 1.75 and min_samples = 2`
#
# Next is example of *four* clusters created on above parameters which share exact left and right context tokens.
#
# Neighbouring context token  of *first* group
# * Left_context is  \[ nationality = \]
# * right_context is \[ other_names = \]

# %%
dbscan_results.groupby((2, 1.75, 2,)).get_group(dbscan_results.groupby((2, 1.75, 2,)).size().sort_values(ascending=False).index[8]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                                            left_context  \
# 0                   resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 1                   resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 2                   resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 3                   resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 4                   resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 5                        resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality =
# 6                        resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality =
# 7                   resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 8                       resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = america , york | nationality =
# 9                        ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 10                       ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 11                       ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 12                          ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = malta | nationality =
# 13        sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 14        sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 15        sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 16        sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 17            , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 18            , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 19            , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 20            , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 21    bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality =
# 22    bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality =
# 23       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 24       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 25       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 26       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 27       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 28       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 29       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 30       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 31       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 32       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 33       sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 34       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 35       , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 36       sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 37       sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 38       sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 39        , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 40  bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 41        , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 42        , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
#
#      del_string_tokens   ins_string_tokens  \
# 0          (scottish,)         (brittish,)
# 1          (brittish,)          (british,)
# 2           (british,)         (scottish,)
# 3          (scottish,)          (british,)
# 4           (british,)         (scottish,)
# 5          (scottish,)          (british,)
# 6           (british,)         (scottish,)
# 7          (scottish,)         (american,)
# 8          (american,)         (scottish,)
# 9          (scottish,)          (british,)
# 10          (british,)         (scottish,)
# 11         (scottish,)          (maltese,)
# 12          (maltese,)         (scottish,)
# 13         (scottish,)             (peru,)
# 14             (peru,)         (scottish,)
# 15         (scottish,)          (british,)
# 16          (british,)         (scottish,)
# 17         (scottish,)          (british,)
# 18          (british,)         (scottish,)
# 19         (scottish,)          (british,)
# 20          (british,)         (scottish,)
# 21         (scottish,)          (british,)
# 22          (british,)         (scottish,)
# 23         (scottish,)          (british,)
# 24          (british,)         (scottish,)
# 25         (scottish,)          (british,)
# 26          (british,)         (scottish,)
# 27         (scottish,)          (british,)
# 28          (british,)         (scottish,)
# 29         (scottish,)          (british,)
# 30          (british,)         (scottish,)
# 31         (scottish,)          (british,)
# 32          (british,)  ([[, scottish, ]])
# 33  ([[, scottish, ]])          (british,)
# 34          (british,)         (scottish,)
# 35         (scottish,)          (british,)
# 36          (british,)         (scottish,)
# 37         (scottish,)          (british,)
# 38          (british,)         (scottish,)
# 39         (scottish,)                  ()
# 40                  ()         (scottish,)
# 41         (scottish,)         (jamaican,)
# 42         (jamaican,)         (scottish,)
#
#                                                                                                                                                      right_context
# 0   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 1   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 2   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 3   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 4   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 5   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 6   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 7   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 8        | other _ names = | citizenship = america | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow <
# 9   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 10  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 11  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 12  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 13  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 14  | other _ names = juan | citizenship = argentina | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 15  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 16  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 17  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 18  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 19  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 20  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 21          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 22          | other _ names = | citizenship = cool place | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now
# 23       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 24       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 25       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 26       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 27       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 28       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 29          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 30          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 31          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 32          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 33          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 34       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 35                                      | other _ names = < ref > < ref > < / ref > < / ref > | citizenship = | education = [[ larchfield academy ]] , helensburgh
# 36       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 37       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 38       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 39          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 40       | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 41          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 42          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[

# %% [markdown]
# Neighbouring context token of *second* group
#
# * Left_context is  \[ Citizenship = \]
# * right_context is \[ education = \]

# %%
dbscan_results.groupby((2, 1.75, 2,)).get_group(dbscan_results.groupby((2, 1.75, 2,)).size().sort_values(ascending=False).index[10]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                                                 left_context  \
# 0                           | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 1                               | lat | long | display = inline }} --> | monuments = | residence = america , york | nationality = american | other _ names = | citizenship =
# 2         resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = | citizenship =
# 3                _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = peru | other _ names = juan | citizenship =
# 4          _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = johnny | citizenship =
# 5            in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = scottish | other _ names = johnny | citizenship =
# 6         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 7          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = british | other _ names = | citizenship =
# 8          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = british | other _ names = | citizenship =
# 9         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 10              _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , | nationality = scottish | other _ names = | citizenship =
# 11      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 12      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 13      _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship
# 14      _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship
# 15      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 16      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 17      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 18      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 19       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 20  baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = armandy argi | citizenship =
# 21       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 22       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 23       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 24       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 25       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 26      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 27      place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 28             _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = | other _ names = | citizenship =
#
#     del_string_tokens                      ins_string_tokens  \
# 0   (united, kingdom)                             (america,)
# 1          (america,)                      (united, kingdom)
# 2   (united, kingdom)                           (argentina,)
# 3        (argentina,)                      (united, kingdom)
# 4   (united, kingdom)  ([[, united, kingdom, |, british, ]])
# 5          (british,)                      (united, kingdom)
# 6   (united, kingdom)                             (british,)
# 7          (british,)                          (cool, place)
# 8       (cool, place)                             (british,)
# 9          (british,)                            (scottish,)
# 10        (scottish,)                             (british,)
# 11         (british,)                           (hscottish,)
# 12       (hscottish,)                             (british,)
# 13       (=, british)                            (scottish,)
# 14        (scottish,)                           (=, british)
# 15         (british,)                              (stupid,)
# 16          (stupid,)                             (british,)
# 17         (british,)                                     ()
# 18                 ()                    (|, citizenship, =)
# 19         (british,)                            (sudanese,)
# 20        (sudanese,)                             (british,)
# 21         (british,)                                     ()
# 22                 ()                             (illegal,)
# 23         (illegal,)                                     ()
# 24                 ()                             (illegal,)
# 25         (illegal,)                                     ()
# 26                 ()                    (|, citizenship, =)
# 27         (british,)                                     ()
# 28                 ()                             (british,)
#
#                                                                                                                                                          right_context
# 0         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 1         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 2         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 3         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 4         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 5    | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ university of strathclyde ]] | occupation
# 6   | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 7   | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 8   | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 9   | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 10  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 11  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 12  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 13  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 14  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 15  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 16  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 17  | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 18      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 19      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 20            | education = student in kukukaka high school | alma _ mater = | occupation = student in kukukaka high school | years _ active = 16 | employer = unknown
# 21      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 22      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 23      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 24      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 25      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 26      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 27      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 28      | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not

# %% [markdown]
# Neighbouring context token of *third* group
#
# * Left_context is  \[  = scotland \]
# * right_context is \[ nationality = \]

# %%
dbscan_results.groupby((2, 1.75, 2,)).get_group(dbscan_results.groupby((2, 1.75, 2,)).size().sort_values(ascending=False).index[12]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                               left_context  \
# 0    helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland ,
# 1    helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland ,
# 2    helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland ,
# 3   [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland
# 4     - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 5     - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 6     - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 7    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland
# 8     on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 9     on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 10    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 11    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 12    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 13    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 14    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 15    - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 16    - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 17    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 18    on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 19  bexhill ]] , [[ sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 20  bexhill ]] , [[ sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 21  on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 22  on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 23   - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
# 24   - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
#
#                  del_string_tokens              ins_string_tokens  \
# 0                       (england,)                          (uk,)
# 1                            (uk,)                     (england,)
# 2                       (england,)                        (york,)
# 3                     (,, england)                             ()
# 4                               ()       (&, trinidad, &, tobago)
# 5         (&, trinidad, &, tobago)                             ()
# 6                               ()  (]], [[, united, kingdom, ]])
# 7         (]], ,, [[, england, ]])                             ()
# 8                       (england,)              (united, kingdom)
# 9                (united, kingdom)                     (england,)
# 10                      (england,)  (the, best, place, on, earth)
# 11   (the, best, place, on, earth)                     (england,)
# 12                      (england,)  (the, best, place, on, earth)
# 13   (the, best, place, on, earth)                     (england,)
# 14                      (england,)                          (uk,)
# 15                         (,, uk)                   (., england)
# 16                    (., england)                   (,, england)
# 17                      (england,)                             ()
# 18                              ()                     (england,)
# 19                      (england,)                (donald, trump)
# 20                 (donald, trump)                     (england,)
# 21                      (england,)                 (argentinian,)
# 22                  (argentinian,)                     (england,)
# 23  (<, br, /, >, [[, england, ]])                             ()
# 24                              ()           (/, [[, england, ]])
#
#                                                                                                                                                               right_context
# 0        | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 1        | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 2        | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 3        | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 4        | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 5   | nationality = scottish & trinidadian | other _ names = | citizenship = united kingdom & trinidad & tobago | education = [[ larchfield academy ]] , helensburgh | alma
# 6           | nationality = scottish | other _ names = johnny | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal
# 7        | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 8       | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 9       | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 10      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 11      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 12      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 13      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 14      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 15      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 16      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 17      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 18     | nationality = scottish | other _ names = | citizenship = scottish | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 19            | nationality = british | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]]
# 20            | nationality = british | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]]
# 21      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 22      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 23      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 24      | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college

# %% [markdown]
# Neighbouring context token of *fourth* group
#
#
# * Left_context is  \[  = Scottish \]
# * right_context is \[  | other_names \]

# %%
dbscan_results.groupby((2, 1.75, 2,)).get_group(dbscan_results.groupby((2, 1.75, 2,)).size().sort_values(ascending=False).index[13]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                                                left_context  \
# 0        | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish
# 1   sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland & trinidad & tobago | nationality = scottish
# 2        | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish
# 3         _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = [[ scotland | scottish
# 4          england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 5          england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 6          england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 7          england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 8          england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 9          england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 10         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 11         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 12         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 13         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 14         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 15         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 16         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 17         england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 18    [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 19    [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 20    [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 21    [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 22     ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 23     ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
#
#                                          del_string_tokens  \
# 0                                                       ()
# 1                                         (&, trinidadian)
# 2                                                       ()
# 3                (]], [[, united, kingdom, |, british, ]])
# 4                                                       ()
# 5                                          ((, british, ))
# 6                                                       ()
# 7                                          ((, british, ))
# 8                                                       ()
# 9                                          ((, british, ))
# 10                                                      ()
# 11                                            (-, british)
# 12                                                      ()
# 13                                            (-, british)
# 14                                                      ()
# 15                                            (-, british)
# 16                                                      ()
# 17                                            (-, british)
# 18                                                      ()
# 19  ({{, citation, needed, |, date, =, november, 2014, }})
# 20                                                      ()
# 21                                              (marsian,)
# 22                                                      ()
# 23                                              (chicken,)
#
#                                          ins_string_tokens  \
# 0                                         (&, trinidadian)
# 1                                                       ()
# 2                                    (]], [[, british, ]])
# 3                                                       ()
# 4                                          ((, british, ))
# 5                                                       ()
# 6                                          ((, british, ))
# 7                                                       ()
# 8                                          ((, british, ))
# 9                                                       ()
# 10                                            (-, british)
# 11                                                      ()
# 12                                            (-, british)
# 13                                                      ()
# 14                                            (-, british)
# 15                                                      ()
# 16                                            (-, british)
# 17                                                      ()
# 18  ({{, citation, needed, |, date, =, november, 2014, }})
# 19                                                      ()
# 20                                              (marsian,)
# 21                                                      ()
# 22                                              (chicken,)
# 23                                                      ()
#
#                                                                                                                                                      right_context
# 0   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 1    | other _ names = | citizenship = united kingdom & trinidad & tobago | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 2    | other _ names = johnny | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ,
# 3           | other _ names = johnny | citizenship = [[ united kingdom | british ]] | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal
# 4   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 5   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 6   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 7   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 8   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 9   | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 10  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 11  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 12  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 13  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 14  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 15  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 16  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 17  | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 18          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 19          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 20          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 21                 | other _ names = | citizenship = british | education = [[ marsian space academy ]] , mars | alma _ mater = [[ royal technical college ]] ( now
# 22          | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 23      | other _ names = logie bear | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] (

# %% [markdown]
# #### Low value of context length finds clusters with less noise but gives more clusters having the similar neighbourhood.
#
# We have got clusters which were having similar neighbourhood but were clustered differently because we considered only the context length of 2. As this gives us lots of clusters who are similar in their neighbourhood, Next we see Completness and V-measure to find out the clusters which has few noises but takes into account bigger context_length to cluster similar change object neighbour hood in one. Hence giving fewer clusters.

# %% [markdown]
# ### Completness

# %%
evaluation_df.reset_index().set_index([ "context","eps",  "min_samples", ])["change_object_completness"].sort_values().iloc[-10:]
# Out:
# context  eps   min_samples
# 8        1.50  50             0.138596
# 30       1.00  50             0.139274
# 8        1.75  50             0.140918
# 15       1.75  50             0.165547
# 20       0.50  50             1.000000
# 30       0.25  50             1.000000
# 15       0.25  50             1.000000
# 25       0.25  50             1.000000
# 20       0.25  50             1.000000
# 15       0.50  50             1.000000
# Name: change_object_completness, dtype: float64

# %%
dbscan_results.groupby((15,0.5,50)).ngroups
# Out:
# 1

# %%
dbscan_results.groupby((20,0.25,50)).ngroups
# Out:
# 1

# %% [markdown]
# #### Trivial clusters of length 1
# Highest value of completness is one implying everything got clustered as one huge cluster hence all instances of same class are in same cluster. As one is trivial case, we need to move to V-measure to find the clusters who are good indicators of clusters where all the attributes about the same groups are in same cluster.

# %% [markdown]
# ### V-measure

# %%
evaluation_df.reset_index().set_index([ "context","eps",  "min_samples", ])\
    ["change_object_vmeasure"].sort_values().iloc[-20:]
# Out:
# context  eps   min_samples
# 20       0.75  10             0.138329
# 15       1.00  20             0.139846
# 25       0.50  20             0.140066
# 8        2.00  20             0.142369
# 10       2.25  50             0.145335
# 15       1.50  30             0.146098
# 30       1.25  50             0.146502
# 25       1.25  50             0.149093
#          0.50  10             0.151193
# 20       1.25  30             0.151276
# 10       1.75  30             0.158588
# 20       1.50  50             0.161853
#          1.00  20             0.162006
# 30       0.75  20             0.162820
# 10       2.00  30             0.168044
#          1.50  20             0.178537
# 30       1.00  50             0.181075
# 8        1.75  20             0.184929
# 10       1.75  20             0.190063
# 15       1.75  50             0.211642
# Name: change_object_vmeasure, dtype: float64

# %% [markdown]
# #### Clusters with some errors
#
# We show cluster pertainig to top V-measure and try to analyse the errors in clusters
# parameters
#
# `Context_length = 15, eps = 1.75 and min_samples = 50`

# %% [markdown]
# ##### Following is an example of cluster which still has similar neighbourhood left and right context but has some noise.
# First observation is clusters which were different in groups above has started to get combined in one hence leading to larger clusters. Second is few noisy change object is getting clustered due to increased context_length.

# %% [markdown]
# ---
#
# #### Kinds of noise which gets added in  both the cluster
# 1. Few of the right context is about education.
# 2. Other names of john loggie baird

# %%
dbscan_results.groupby((15, 1.75, 50,)).get_group(dbscan_results.groupby((15, 1.75, 50,)).size().sort_values(ascending=False).index[2]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                                                     left_context  \
# 0                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 1                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 2                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 3                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 4                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 5                                 resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality =
# 6                                       <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality = british | other _ names =
# 7                                       <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality = british | other _ names =
# 8                                 resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality =
# 9                                 <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 10                                <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 11                           resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 12                              | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 13                               resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = america , york | nationality =
# 14                                ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 15                                ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 16                                ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 17                                   ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = malta | nationality =
# 18                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 19                , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names =
# 20            resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = | citizenship =
# 21                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 22                    , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = peru | other _ names =
# 23                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 24                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 25                          - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 26            | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish
# 27       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = | citizenship = united kingdom
# 28   [[ helensburgh cemetery ]] | monuments = | residence = scotland & trinidad & tobago | nationality = scottish & trinidadian | other _ names = | citizenship = united kingdom
# 29                , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names =
# 30                          - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 31                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 32            | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish
# 33             _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = johnny | citizenship =
# 34                         - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
# 35                        sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[
# 36               in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = scottish | other _ names = johnny | citizenship =
# 37                 = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = scottish | other _ names =
# 38              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 39              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 40              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 41              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 42              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 43              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 44              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 45              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 46              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 47              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 48              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 49              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 50              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 51              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 52                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 53                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 54                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 55                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 56                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland
# 57                | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 58                | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 59            place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 60             bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality =
# 61             place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = british | other _ names = | citizenship =
# 62             bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality =
# 63             place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = british | other _ names = | citizenship =
# 64            place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 65                  _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , | nationality = scottish | other _ names = | citizenship =
# 66          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 67          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 68          _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship
# 69          _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship
# 70          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 71          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 72              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 73              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 74         [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 75         [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 76          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 77                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 78                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 79                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 80                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 81                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 82                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 83              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 84          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 85        = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | citizenship = british | other _ names =
# 86         [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 87         [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 88                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 89                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 90                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 91               | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 92           place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 93               | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 94                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 95                sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 96           place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 97                , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 98               | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 99              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 100          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 101          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 102          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 103          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 104               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 105               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 106               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 107             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 108         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 109       = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | citizenship = british | other _ names =
# 110             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 111             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 112                , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 113         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 114          bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 115                _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = | other _ names = | citizenship =
# 116                , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 117                , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 118         ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 119             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 120         ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 121       resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish chicken | other _ names =
# 122                  - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england
# 123                        - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
# 124                        - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
#
#                                           del_string_tokens  \
# 0                                               (scottish,)
# 1                                               (brittish,)
# 2                                                (british,)
# 3                                               (scottish,)
# 4                                                (british,)
# 5                                               (scottish,)
# 6                                                        ()
# 7                                                 (mr, fat)
# 8                                                (british,)
# 9                                                        ()
# 10                                                 (hello,)
# 11                                              (scottish,)
# 12                                        (united, kingdom)
# 13                                              (american,)
# 14                                              (scottish,)
# 15                                               (british,)
# 16                                              (scottish,)
# 17                                               (maltese,)
# 18                                              (scottish,)
# 19                                                       ()
# 20                                        (united, kingdom)
# 21                                                  (peru,)
# 22                                                  (juan,)
# 23                                              (scottish,)
# 24                                               (british,)
# 25                                                       ()
# 26                                                       ()
# 27                                                       ()
# 28                                 (&, trinidad, &, tobago)
# 29                                                       ()
# 30                                                       ()
# 31                                                       ()
# 32                                                       ()
# 33                                        (united, kingdom)
# 34                                                       ()
# 35                                        (united, kingdom)
# 36                                               (british,)
# 37                                                (johnny,)
# 38                                                       ()
# 39                                          ((, british, ))
# 40                                                       ()
# 41                                          ((, british, ))
# 42                                                       ()
# 43                                          ((, british, ))
# 44                                                       ()
# 45                                             (-, british)
# 46                                                       ()
# 47                                             (-, british)
# 48                                                       ()
# 49                                             (-, british)
# 50                                                       ()
# 51                                             (-, british)
# 52                                              (scottish,)
# 53                                               (british,)
# 54                                              (scottish,)
# 55                                               (british,)
# 56                                 (]], ,, [[, england, ]])
# 57                                                       ()
# 58                                    (mario, kart, genius)
# 59                                        (united, kingdom)
# 60                                              (scottish,)
# 61                                               (british,)
# 62                                               (british,)
# 63                                            (cool, place)
# 64                                               (british,)
# 65                                              (scottish,)
# 66                                               (british,)
# 67                                             (hscottish,)
# 68                                             (=, british)
# 69                                              (scottish,)
# 70                                               (british,)
# 71                                                (stupid,)
# 72                                                       ()
# 73                                                   (ass,)
# 74                                                       ()
# 75   ({{, citation, needed, |, date, =, november, 2014, }})
# 76                                               (british,)
# 77                                              (scottish,)
# 78                                               (british,)
# 79                                              (scottish,)
# 80                                               (british,)
# 81                                              (scottish,)
# 82                                               (british,)
# 83                                                       ()
# 84                                                       ()
# 85                                      (|, citizenship, =)
# 86                                                       ()
# 87                                               (marsian,)
# 88                                              (scottish,)
# 89                                               (british,)
# 90                                              (scottish,)
# 91                                                       ()
# 92                                               (british,)
# 93                                          (armandy, argi)
# 94                                               (british,)
# 95                                       ([[, scottish, ]])
# 96                                               (british,)
# 97                                               (british,)
# 98                                                       ()
# 99       (<, ref, >, <, ref, >, <, /, ref, >, <, /, ref, >)
# 100                                                      ()
# 101                                              (illegal,)
# 102                                                      ()
# 103                                              (illegal,)
# 104                                              (british,)
# 105                                             (scottish,)
# 106                                              (british,)
# 107                                                      ()
# 108                                                      ()
# 109                                     (|, citizenship, =)
# 110                                                      ()
# 111                                              (dickboy,)
# 112                                             (scottish,)
# 113                                              (british,)
# 114                                                      ()
# 115                                                      ()
# 116                                             (scottish,)
# 117                                             (jamaican,)
# 118                                                      ()
# 119                                                      ()
# 120                                              (chicken,)
# 121                                           (logie, bear)
# 122                                                      ()
# 123                          (<, br, /, >, [[, england, ]])
# 124                                                      ()
#
#                                           ins_string_tokens  \
# 0                                               (brittish,)
# 1                                                (british,)
# 2                                               (scottish,)
# 3                                                (british,)
# 4                                               (scottish,)
# 5                                                (british,)
# 6                                                 (mr, fat)
# 7                                                        ()
# 8                                               (scottish,)
# 9                                                  (hello,)
# 10                                                       ()
# 11                                              (american,)
# 12                                               (america,)
# 13                                              (scottish,)
# 14                                               (british,)
# 15                                              (scottish,)
# 16                                               (maltese,)
# 17                                              (scottish,)
# 18                                                  (peru,)
# 19                                                  (juan,)
# 20                                             (argentina,)
# 21                                              (scottish,)
# 22                                                       ()
# 23                                               (british,)
# 24                                              (scottish,)
# 25                                 (&, trinidad, &, tobago)
# 26                                         (&, trinidadian)
# 27                                 (&, trinidad, &, tobago)
# 28                                                       ()
# 29                                                (johnny,)
# 30                            (]], [[, united, kingdom, ]])
# 31                                                    ([[,)
# 32                                    (]], [[, british, ]])
# 33                    ([[, united, kingdom, |, british, ]])
# 34                                                     (,,)
# 35                                               (england,)
# 36                                        (united, kingdom)
# 37                                                       ()
# 38                                          ((, british, ))
# 39                                                       ()
# 40                                          ((, british, ))
# 41                                                       ()
# 42                                          ((, british, ))
# 43                                                       ()
# 44                                             (-, british)
# 45                                                       ()
# 46                                             (-, british)
# 47                                                       ()
# 48                                             (-, british)
# 49                                                       ()
# 50                                             (-, british)
# 51                                                       ()
# 52                                               (british,)
# 53                                              (scottish,)
# 54                                               (british,)
# 55                                              (scottish,)
# 56                                                       ()
# 57                                    (mario, kart, genius)
# 58                                                       ()
# 59                                               (british,)
# 60                                               (british,)
# 61                                            (cool, place)
# 62                                              (scottish,)
# 63                                               (british,)
# 64                                              (scottish,)
# 65                                               (british,)
# 66                                             (hscottish,)
# 67                                               (british,)
# 68                                              (scottish,)
# 69                                             (=, british)
# 70                                                (stupid,)
# 71                                               (british,)
# 72                                                   (ass,)
# 73                                                       ()
# 74   ({{, citation, needed, |, date, =, november, 2014, }})
# 75                                                       ()
# 76                                                       ()
# 77                                               (british,)
# 78                                              (scottish,)
# 79                                               (british,)
# 80                                              (scottish,)
# 81                                               (british,)
# 82                                              (scottish,)
# 83                                               (british,)
# 84                                      (|, citizenship, =)
# 85                                                       ()
# 86                                               (marsian,)
# 87                                                       ()
# 88                                               (british,)
# 89                                              (scottish,)
# 90                                               (british,)
# 91                                          (armandy, argi)
# 92                                              (sudanese,)
# 93                                                       ()
# 94                                       ([[, scottish, ]])
# 95                                               (british,)
# 96                                                       ()
# 97                                              (scottish,)
# 98       (<, ref, >, <, ref, >, <, /, ref, >, <, /, ref, >)
# 99                                                       ()
# 100                                              (illegal,)
# 101                                                      ()
# 102                                              (illegal,)
# 103                                                      ()
# 104                                             (scottish,)
# 105                                              (british,)
# 106                                             (scottish,)
# 107                                              (british,)
# 108                                     (|, citizenship, =)
# 109                                                      ()
# 110                                              (dickboy,)
# 111                                                      ()
# 112                                                      ()
# 113                                                      ()
# 114                                             (scottish,)
# 115                                              (british,)
# 116                                             (jamaican,)
# 117                                             (scottish,)
# 118                                              (chicken,)
# 119                                           (logie, bear)
# 120                                                      ()
# 121                                                      ()
# 122                                                   (]],)
# 123                                                      ()
# 124                                    (/, [[, england, ]])
#
#                                                                                                                                                                 right_context
# 0              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 1              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 2              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 3              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 4              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 5              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 6              | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow
# 7              | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow
# 8              | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 9              | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow
# 10             | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow
# 11             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 12               | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 13                  | other _ names = | citizenship = america | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow <
# 14             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 15             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 16             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 17             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 18             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 19             | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow
# 20               | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 21             | other _ names = juan | citizenship = argentina | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 22       | citizenship = argentina | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university
# 23             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 24             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 25         | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 26             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 27               | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 28               | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 29             | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow
# 30            | nationality = scottish | other _ names = johnny | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal
# 31       scottish | other _ names = johnny | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]]
# 32              | other _ names = johnny | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ,
# 33               | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ glasgow university ]] | occupation =
# 34         [[ united kingdom ]] | nationality = scottish | other _ names = johnny | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater
# 35                ]] | nationality = scottish | other _ names = johnny | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal
# 36          | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ university of strathclyde ]] | occupation
# 37              | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow < br > [[ university of
# 38             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 39             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 40             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 41             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 42             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 43             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 44             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 45             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 46             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 47             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 48             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 49             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 50             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 51             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 52             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 53             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 54             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 55             | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] , glasgow
# 56         | nationality = scottish | other _ names = | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 57   | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]]
# 58   | citizenship = united kingdom | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]]
# 59         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 60                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 61         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 62                     | other _ names = | citizenship = cool place | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now
# 63         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 64         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 65         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 66         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 67         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 68         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 69         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 70         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 71         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 72        | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 73        | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 74                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 75                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 76         | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 77                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 78                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 79                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 80                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 81                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 82                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 83                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 84             | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 85             | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 86                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 87                            | other _ names = | citizenship = british | education = [[ marsian space academy ]] , mars | alma _ mater = [[ royal technical college ]] ( now
# 88                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 89                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 90                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 91        | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 92             | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 93               | citizenship = sudanese | education = student in kukukaka high school | alma _ mater = | occupation = student in kukukaka high school | years _ active = 16
# 94                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 95                     | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 96             | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 97                  | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 98              | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) ,
# 99              | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) ,
# 100            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 101            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 102            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 103            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 104                 | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 105                 | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 106                 | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 107                 | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 108            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 109            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 110       | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 111       | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 112                    | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 113            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 114                 | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 115            | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 116                    | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 117                    | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 118                    | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 119       | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 120                | other _ names = logie bear | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] (
# 121       | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 122       | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 123       | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 124       | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college

# %% [markdown]
# *First three  entry has different neighbourhood and is about the name of the john loggie baird.*

# %%
dbscan_results.groupby((15, 1.75, 50,)).get_group(dbscan_results.groupby((15, 1.75, 50,)).size().sort_values(ascending=False).index[4]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                                  left_context  \
# 0                          | image = john logie baird , bust . jpg | image _ width = 250px | caption = bust of john logie baird in [[ helensburgh ]] | name =
# 1                         image = john logie baird , bust . jpg | image _ width = 250px | caption = bust of john logie baird in [[ helensburgh ]] | name = {{
# 2                         image = john logie baird , bust . jpg | image _ width = 250px | caption = bust of john logie baird in [[ helensburgh ]] | name = {{
# 3                        {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 4                       image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality = [[ scotland | scottish
# 5                        {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 6                        {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 7                        {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 8                        {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 9                             baird }} {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird |
# 10                       {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 11                       {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 12                       {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 13                       {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 14                       {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 15                       {{ infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality =
# 16                 infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality = scottish
# 17                 infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality = scottish
# 18                 infobox engineer | image = jl - baird - scottish - inventor - of - tv . jpg | caption = | name = john logie baird | nationality = scottish
# 19                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 20                          St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = scottish
# 21                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 22                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 23                          St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = scottish
# 24                          St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = scottish
# 25                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 26                          St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = scottish
# 27                                St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[
# 28                     St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ scotland |
# 29                                St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[
# 30               St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ united kingdom |
# 31                                St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[
# 32                     St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ scotland |
# 33                                St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[
# 34               St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ united kingdom |
# 35                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 36            St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ scotland | scottish
# 37  otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ scotland | scottish ]] | citizenship =
# 38                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 39                          St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = scottish
# 40          St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = scottish | citizenship =
# 41                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 42            St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ scotland | scottish
# 43  otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality = [[ scotland | scottish ]] | citizenship =
# 44                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 45                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 46                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 47                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 48                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 49                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 50                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 51                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 52                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 53                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 54                                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird
# 55                                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird
# 56                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 57                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 58                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 59                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 60                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
# 61                                   St@rt {{ otherpeople | john baird }} {{ infobox engineer | image = | caption = | name = john logie baird | nationality =
#
#                   del_string_tokens  \
# 0                                ()
# 1                                ()
# 2                       (pagename,)
# 3                 ([[, scotland, |)
# 4                             (]],)
# 5                       (scottish,)
# 6                        (british,)
# 7                       (scottish,)
# 8                        (british,)
# 9                    (nationality,)
# 10                      (scottish,)
# 11                (united, kingdom)
# 12                      (scottish,)
# 13                       (british,)
# 14                      (scottish,)
# 15                       (british,)
# 16                               ()
# 17                     (/, british)
# 18  ((, only, scottish, !, !, !, ))
# 19                               ()
# 20                     (/, british)
# 21           (british, /, scottish)
# 22                       (british,)
# 23                               ()
# 24                           (:, l)
# 25                               ()
# 26                               ()
# 27                      (scotland,)
# 28                      (scottish,)
# 29                (united, kingdom)
# 30                       (british,)
# 31                      (scotland,)
# 32                      (scottish,)
# 33                (united, kingdom)
# 34                       (british,)
# 35                ([[, scotland, |)
# 36                            (]],)
# 37               ([[, scotland, ]])
# 38                               ()
# 39                               ()
# 40                               ()
# 41                ([[, scotland, |)
# 42                            (]],)
# 43               ([[, scotland, ]])
# 44                      (scottish,)
# 45                       (british,)
# 46                      (scottish,)
# 47                       (british,)
# 48                      (scottish,)
# 49                      (american,)
# 50                      (scottish,)
# 51                       (british,)
# 52                      (scottish,)
# 53                       (british,)
# 54                               ()
# 55                  (kiss, my, ass)
# 56                      (scottish,)
# 57                       (british,)
# 58                      (scottish,)
# 59                       (british,)
# 60                      (scottish,)
# 61                       (british,)
#
#                                                ins_string_tokens  \
# 0                                           (john, logie, baird)
# 1                                                     (reflist,)
# 2                                                             ()
# 3                                                             ()
# 4                                                             ()
# 5                                                     (british,)
# 6                                                    (scottish,)
# 7                                                     (british,)
# 8                                                    (scottish,)
# 9                                                    (scottish,)
# 10                                             (united, kingdom)
# 11                                                   (scottish,)
# 12                                                    (british,)
# 13                                                   (scottish,)
# 14                                                    (british,)
# 15                                                   (scottish,)
# 16                                                  (/, british)
# 17                               ((, only, scottish, !, !, !, ))
# 18                                                  (/, british)
# 19                                                  (british, /)
# 20                                                            ()
# 21                                                    (british,)
# 22                                                   (scottish,)
# 23                                                        (:, l)
# 24                                                            ()
# 25                                             ([[, scotland, |)
# 26  (]], |, citizenship, =, [[, united, kingdom, |, british, ]])
# 27                                             (united, kingdom)
# 28                                                    (british,)
# 29                                                   (scotland,)
# 30                                                   (scottish,)
# 31                                             (united, kingdom)
# 32                                                    (british,)
# 33                                                   (scotland,)
# 34                                                   (scottish,)
# 35                                                            ()
# 36                                                            ()
# 37                                                            ()
# 38                                             ([[, scotland, |)
# 39                                                         (]],)
# 40                                            ([[, scotland, ]])
# 41                                                            ()
# 42                                                            ()
# 43                                                            ()
# 44                                                    (british,)
# 45                                                   (scottish,)
# 46                                                    (british,)
# 47                                                   (scottish,)
# 48                                                   (american,)
# 49                                                   (scottish,)
# 50                                                    (british,)
# 51                                                   (scottish,)
# 52                                                    (british,)
# 53                                                   (scottish,)
# 54                                               (kiss, my, ass)
# 55                                                            ()
# 56                                                    (british,)
# 57                                                   (scottish,)
# 58                                                    (british,)
# 59                                                   (scottish,)
# 60                                                    (british,)
# 61                                                   (scottish,)
#
#                                                                                                                                               right_context
# 0                         }} | nationality = [[ scotland | scottish ]] | birth _ date = [[ august 13 ]] [[ 1888 ]] | birth _ place = [[ helensburgh ]] , [[
# 1                     | nationality = [[ scotland | scottish ]] | birth _ date = [[ august 13 ]] [[ 1888 ]] | birth _ place = [[ helensburgh ]] , [[ argyll
# 2                         }} | nationality = [[ scotland | scottish ]] | birth _ date = [[ august 13 ]] [[ 1888 ]] | birth _ place = [[ helensburgh ]] , [[
# 3                     scottish ]] | birth _ date = [[ august 13 ]] [[ 1888 ]] | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] |
# 4                         | birth _ date = [[ august 13 ]] [[ 1888 ]] | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death _
# 5                     | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 6                     | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 7                     | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 8                     | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 9                 = scottish | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june
# 10                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 11                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 12                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 13                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 14                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 15                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 16                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 17                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 18                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 19             scottish / british | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14
# 20                    | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = 14 june 1946 |
# 21                 | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = {{ death date and
# 22                 | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = {{ death date and
# 23                 | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = {{ death date and
# 24                 | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = {{ death date and
# 25            scottish | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = {{ death date
# 26                 | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , scotland | death _ date = {{ death date and
# 27     | scottish ]] | citizenship = [[ united kingdom | british ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire
# 28           ]] | citizenship = [[ united kingdom | british ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] ,
# 29           | british ]] | citizenship = [[ united kingdom ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] ,
# 30           ]] | citizenship = [[ united kingdom ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ united
# 31          | scottish ]] | citizenship = [[ united kingdom ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] ,
# 32         ]] | citizenship = [[ united kingdom ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland
# 33           | british ]] | citizenship = [[ united kingdom ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] ,
# 34           ]] | citizenship = [[ united kingdom ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ united
# 35      scottish ]] | citizenship = [[ scotland ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland
# 36             | citizenship = [[ scotland ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] ,
# 37               | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] , [[ united kingdom ]] | death
# 38    scottish | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] |
# 39       | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 40              united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death _ date =
# 41      scottish ]] | citizenship = [[ scotland ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland
# 42             | citizenship = [[ scotland ]] | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] ,
# 43               | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] , [[ united kingdom ]] | death
# 44       | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 45       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 46       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 47       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 48       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 49       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 50       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 51       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 52       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 53       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 54  | nationality = scottish | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[
# 55  | nationality = scottish | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[
# 56       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 57       | citizenship = united kingdom | birth _ date = 14 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 58       | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 59       | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 60       | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death
# 61       | citizenship = united kingdom | birth _ date = 13 august 1888 | birth _ place = [[ helensburgh ]] , [[ dunbartonshire ]] , [[ scotland ]] | death

# %% [markdown]
# # Identifying worst clusters

# %% [markdown]
# **We see the median value of V-measure to see the increase in error in clusters.**

# %%
evaluation_df.reset_index().set_index([ "context","eps",  "min_samples", ])\
["change_object_vmeasure"].sort_values().iloc[384:385]
# Out:
# context  eps   min_samples
# 25       1.75  20             0.047735
# Name: change_object_vmeasure, dtype: float64

# %% [markdown]
# `parameters context_length=25, eps = 1.75, min_samples=20`
#
# We can see that noise has considerably increased compared to best V-measure

# %%
dbscan_results.groupby((25,1.75,20)).get_group(dbscan_results.groupby((25,1.75,20)).size().sort_values(ascending=False).index[2]).reset_index()[[ 'left_context',
     'del_string_tokens',  'ins_string_tokens',   'right_context']]
# Out:
#                                                                                                                                                                     left_context  \
# 0                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 1                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 2                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 3                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 4                            resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 5                                                                   8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | death _ cause =
# 6                          helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland ,
# 7                                 resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality =
# 8                                                                   8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | death _ cause =
# 9                                                    y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | death _ cause = stroke | body _ discovered =
# 10                                      <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality = british | other _ names =
# 11                                      <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality = british | other _ names =
# 12                                resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , uk | nationality =
# 13                         helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland ,
# 14                                                                      | 14 | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england
# 15                                <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 16                                <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 17                             family grave in [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = |
# 18                             family grave in [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = |
# 19                                                                            6 | 14 | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex ,
# 20                              in [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence =
# 21                         helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland ,
# 22                           resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality =
# 23                              | lat | long | display = inline }} --> | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 24                                                                            6 | 14 | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex ,
# 25                              in [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence =
# 26                          helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = america ,
# 27                               resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = america , york | nationality =
# 28                                  | lat | long | display = inline }} --> | monuments = | residence = america , york | nationality = american | other _ names = | citizenship =
# 29                        [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland
# 30                                ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 31                                ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 32                                                                      14 | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england |
# 33                                                                      14 | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england |
# 34                                                                  | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | anthea
# 35                                                            | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | death cause = by anthea
# 36                              in [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence =
# 37                                ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = scotland | nationality =
# 38                              in [[ helensburgh cemetery ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence =
# 39                                   ]] | resting _ place _ coordinates = <!-- {{ coord | lat | long | display = inline }} --> | monuments = | residence = malta | nationality =
# 40                                                                      | 14 | 1888 | 8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england
# 41                          | bexhill ]] , sussex , england | death cause = by anthea | body _ discovered = | resting _ place = baird family grave in [[ helensburgh cemetery ]]
# 42                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 43                , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names =
# 44            resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = | citizenship =
# 45                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 46                   _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = peru | other _ names = juan | citizenship =
# 47                    , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = peru | other _ names =
# 48                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 49                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 50                          - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 51            | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish
# 52       place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = | citizenship = united kingdom
# 53                          - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 54       sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland & trinidad & tobago | nationality = scottish
# 55   [[ helensburgh cemetery ]] | monuments = | residence = scotland & trinidad & tobago | nationality = scottish & trinidadian | other _ names = | citizenship = united kingdom
# 56                , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names =
# 57                           bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 58                          - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 59                 sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality =
# 60            | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish
# 61             _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland | nationality = scottish | other _ names = johnny | citizenship =
# 62               england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = [[
# 63                  _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = [[ scottish ]] [[
# 64                                                   = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[
# 65                              place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments =
# 66                                            }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ personal =
# 67                              place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments =
# 68                              place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments =
# 69                , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality =
# 70             _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = [[ scotland | scottish
# 71                       = [[ scotland ]] [[ united kingdom ]] | nationality = [[ scotland | scottish ]] [[ united kingdom | british ]] | other _ names = johnny | citizenship =
# 72               united kingdom ]] | nationality = [[ scotland | scottish ]] [[ united kingdom | british ]] | other _ names = johnny | citizenship = [[ united kingdom | british
# 73                         - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
# 74                        sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[
# 75               in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = scottish | other _ names = johnny | citizenship =
# 76                 = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] [[ united kingdom ]] | nationality = scottish | other _ names =
# 77              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 78              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 79              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 80              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 81              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 82              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 83                         ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish | other _ names = | citizenship = united kingdom | education =
# 84                         ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish | other _ names = | citizenship = united kingdom | education =
# 85              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 86              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 87              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 88              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 89              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 90              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 91              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 92              england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality = scottish
# 93                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 94                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 95                                                                8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place =
# 96                                                                8 | 13 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place =
# 97                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 98                     , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] , [[ england ]] | nationality =
# 99                                - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[
# 100                        on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland
# 101                          bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 102                          bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 103               | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 104               | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names =
# 105                                                               8 | 14 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place =
# 106                                                               8 | 14 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place =
# 107           place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 108            bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality =
# 109            place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = british | other _ names = | citizenship =
# 110            bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality =
# 111            place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = british | other _ names = | citizenship =
# 112                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 113                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 114                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 115                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 116                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 117                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 118                                                                           6 | 14 | 1888 | 8 | 14 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex ,
# 119                                                                           6 | 14 | 1888 | 8 | 14 | df = y }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex ,
# 120                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 121                         - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 122                         - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 123           place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , england | nationality = scottish | other _ names = | citizenship =
# 124                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 125                         on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland ,
# 126                 _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland , | nationality = scottish | other _ names = | citizenship =
# 127                         - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 128         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 129         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 130         _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship
# 131         _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship
# 132         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 133         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 134             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 135             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 136                                                                           df = yes | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] ,
# 137                                                                       = yes | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex
# 138        [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 139        [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 140         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 141               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 142               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 143               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 144               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 145               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 146               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 147             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 148         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 149       = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | citizenship = british | other _ names =
# 150                              on - sea | bexhill ]] , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 151                              on - sea | bexhill ]] , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 152                              on - sea | bexhill ]] , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 153                              on - sea | bexhill ]] , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 154        [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 155           in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship = british | education = [[
# 156              ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] ,
# 157      [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish marsian | other _ names = | citizenship = british | education = [[
# 158        monuments = | residence = scotland and england | nationality = scottish marsian | other _ names = | citizenship = british | education = [[ marsian space academy ]] ,
# 159        [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 160               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 161               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 162               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 163              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 164          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 165         grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship = british | education =
# 166              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 167                                                                    | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , [[ sussex ]] , england
# 168               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 169               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 170                                                                    | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , [[ sussex ]] , england
# 171          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 172               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 173              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 174               , [[ sussex ]] , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 175             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 176                                                                    | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , [[ sussex ]] , england
# 177                                                                    | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , [[ sussex ]] , england
# 178                                                                    | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , [[ sussex ]] , england
# 179                       bexhill ]] , [[ sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 180                       bexhill ]] , [[ sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 181          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 182          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 183          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 184          place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names = | citizenship =
# 185               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 186               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 187               sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 188             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 189         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 190       = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | citizenship = british | other _ names =
# 191                                                                           df = yes | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] ,
# 192                                                                      yes | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , [[ sussex
# 193             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 194             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 195                                                                   | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england
# 196                , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 197         place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship =
# 198                                                                   | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england
# 199          bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 200                _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = | other _ names = | citizenship =
# 201                , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 202                , sussex , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 203                                                                   | 1946 | 6 | 14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england
# 204                                       14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh
# 205                                       14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh
# 206                       on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 207                       on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and
# 208         ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 209             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 210         ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish
# 211       resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish chicken | other _ names =
# 212                          bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence =
# 213                         - on - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland
# 214                  - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england
# 215                        - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
# 216                        - sea | bexhill ]] , sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]]
# 217                                                            14 | 1888 | 8 | 14 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place =
# 218                                      }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = [[ helensburgh cemetery ]] | monuments =
# 219                                                              4 | 1930 | 1 | 5 }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place =
# 220                                      }} | death _ place = [[ bexhill - on - sea | bexhill ]] , sussex , england | resting _ place = [[ helensburgh cemetery ]] | monuments =
#
#                                                                                                                                                                                                 del_string_tokens  \
# 0                                                                                                                                                                                                     (scottish,)
# 1                                                                                                                                                                                                     (brittish,)
# 2                                                                                                                                                                                                      (british,)
# 3                                                                                                                                                                                                     (scottish,)
# 4                                                                                                                                                                                                      (british,)
# 5                                                                                                                                                                                                              ()
# 6                                                                                                                                                                                                      (england,)
# 7                                                                                                                                                                                                     (scottish,)
# 8                                                                                                                                                                                                       (stroke,)
# 9                                                                                                                                                                                                              ()
# 10                                                                                                                                                                                                             ()
# 11                                                                                                                                                                                                      (mr, fat)
# 12                                                                                                                                                                                                     (british,)
# 13                                                                                                                                                                                                          (uk,)
# 14                                                                                                                                                                                                             ()
# 15                                                                                                                                                                                                             ()
# 16                                                                                                                                                                                                       (hello,)
# 17                                                                                                                                                                                                   (residence,)
# 18                                                                                                                                                                    (resi, ', ', ', bold, text, ', ', ', dence)
# 19                                                                                                                                                                                                     (england,)
# 20                                                                                                                                                                                                    (scotland,)
# 21                                                                                                                                                                                                     (england,)
# 22                                                                                                                                                                                                    (scottish,)
# 23                                                                                                                                                                                              (united, kingdom)
# 24                                                                                                                                                                                                       (china,)
# 25                                                                                                                                                                                                     (america,)
# 26                                                                                                                                                                                                        (york,)
# 27                                                                                                                                                                                                    (american,)
# 28                                                                                                                                                                                                     (america,)
# 29                                                                                                                                                                                                   (,, england)
# 30                                                                                                                                                                                                    (scottish,)
# 31                                                                                                                                                                                                     (british,)
# 32                                                                                                                                                                                              (death, _, cause)
# 33                                                                                                                                                                                                             ()
# 34                                                                                                                                                                                                    (=, stroke)
# 35                                                                                                                                                                                                    (micallef,)
# ...
# 132          | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 133          | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 134         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 135         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 136     sussex , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other
# 137          , england | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _
# 138                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 139                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 140          | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow | occupation
# 141                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 142                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 143                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 144                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 145                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 146                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 147                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 148              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 149              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 150         england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 151         england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 152         england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 153         england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 154                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 155  academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not strathclyde university --> | occupation
# 156           | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not strathclyde university --> | occupation = inventor < br
# 157         academy ]] , mars | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not strathclyde university --> | occupation
# 158           | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not strathclyde university --> | occupation = inventor < br
# 159                             | other _ names = | citizenship = british | education = [[ marsian space academy ]] , mars | alma _ mater = [[ royal technical college ]] ( now
# 160                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 161                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 162                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 163         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 164              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 165           | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not strathclyde university --> | occupation = inventor < br
# 166                | citizenship = sudanese | education = student in kukukaka high school | alma _ mater = | occupation = student in kukukaka high school | years _ active = 16
# 167             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 168                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 169                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 170              | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = [[ scottish ]] | other _
# 171              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 172                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 173               | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) ,
# 174                                                  | other _ names = < ref > < ref > < / ref > < / ref > | citizenship = | education = [[ larchfield academy ]] , helensburgh
# 175               | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) ,
# 176             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 177             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 178             | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = british | other _ names =
# 179               | nationality = british | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]]
# 180               | nationality = british | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]]
# 181              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 182              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 183              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 184              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 185                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 186                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 187                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 188                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 189              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 190              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 191              sussex ]] , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality =
# 192             , england , uk | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish |
# 193         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 194         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 195            | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 196                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 197              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 198                   | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = | other _ names = |
# 199                   | other _ names = | citizenship = | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university
# 200              | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] ) , glasgow <!-- not
# 201                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 202                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 203            | resting _ place = baird family grave in [[ helensburgh cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names =
# 204      cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]]
# 205      cemetery ]] | monuments = | residence = scotland and england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]]
# 206         | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 207         | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 208                      | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[
# 209         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 210                  | other _ names = logie bear | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] (
# 211         | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college ]] ( now [[ university of strathclyde ]] )
# 212            scotland and england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[
# 213         england | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical
# 214         | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 215         | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 216         | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] , helensburgh | alma _ mater = [[ royal technical college
# 217                  [[ helensburgh cemetery ]] | monuments = | residence = [[ scotland ]] / [[ england ]] | nationality = scottish | other _ names = | citizenship = british |
# 218                    | residence = [[ scotland ]] / [[ england ]] | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] ,
# 219               [[ helensburgh cemetery ]] | monuments = january 2011 | residence = [[ scotland ]] / [[ england ]] | nationality = scottish | other _ names = | citizenship =
# 220                    | residence = [[ scotland ]] / [[ england ]] | nationality = scottish | other _ names = | citizenship = british | education = [[ larchfield academy ]] ,

# %%
pd.set_option('expand_frame_repr', False)
pd.reset_option('display.max_colwidth')
