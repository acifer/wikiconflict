# %% [markdown]
# # Visualisation for clusters of an article
#  This notebook Visualises and compares change object as clustered according to **Bykau et. al** and using **Word2vec** for an article. Given an **article_name** it shows creation and deletion portion of each clusters along with showing revision_id editor and time as index.

# %%
import sys
import os
import pickle
from string import punctuation
from string import whitespace


import matplotlib.pyplot as plt
from IPython.display import HTML

from ipywidgets import interact, interactive, fixed, interact_manual, HBox

import ipywidgets as widgets
import pandas as pd
import numpy as np

sys.path.append("../")

# %%
table_style =     [
    {'selector': 'table', 'props': [('border', "6px double #696969")]},
    {'selector': 'th', 'props': [('border', "2px solid #D3D3D3"), ("font-size", "100%")]},
    {"selector":".data", "props":[("text-align", "justify"), ('border', "1px solid #000"), ('margin', '4px 24px 4px 24px' ), ("font-size", "8pt")]}
] 

deleted_token_style = {"color":"red", "font-weight": "bold","font-size": "100px"}
inserted_token_style = {"color":"blue", "font-weight": "bold","font-size": "100px"}

# %%
with open("../../wordvectors/vocabs.pkl", "rb") as file:
    vocab = pickle.load(file)

# %%
### getting the vlaue of the article to visualise data.
article_name = "Truth"

# %% [markdown]
# ### We first read and visualise the clusters done using vectors prepeared by Using pre trained word2vec vector.
#
# Word tokens in change objects are converted into vector space by using 300 dimensions of pre-trained fast text pre trained embedding vectors. Size of the vocobulary loaded is 1 million words.
#
# Each change object is represented by concatinating  vectors representing left neighbour tokens, insert and delete tokens and right neighbour tokens. Insert and delete tokens vectors is average of fast-text vector representation of each words in token. Left and right neighbours are prepared by taking weighted average of vectors representated by word2vec embeddings. Weights are created by a exponential decay functions whose parameter is  neighbouring token's distance from inserted and deleted word.

# %% [markdown]
# #### Reading change object

# %%
change_object_dir = "../data/change objects/"
content_file = article_name + "_change.h5"
change_object_path = os.path.join(change_object_dir, content_file)

with pd.HDFStore(change_object_path, 'r') as store:
    #retrieving all rev list and change object from file
    change_df = store.get("data")
change_df.shape
# Out:
# (31777, 12)

# %% [markdown]
# ## Remove bigger change object.

# %%
change_df["ins_length"]= change_df["ins_tokens"].apply(lambda x: len(x))
change_df["del_length"]= change_df["del_tokens"].apply(lambda x: len(x))

optimised_change_object_mask = ((change_df["ins_length"] <= 20 ) & (change_df["del_length"] <= 20))

optimised_df = change_df[optimised_change_object_mask].copy()

optimised_df.shape
# Out:
# (25193, 14)

# %% [markdown]
# ### Make left, ins and delete string for visualisation

# %%
change_df["ins_token_len"] = change_df["ins_tokens"].str.len()
change_df["del_token_len"] = change_df["del_tokens"].str.len()

# %% [markdown]
# ##### Reading revision clusters.

# %%
cluster_dir = "../data/clusters/"
file_name = article_name + "_optimised_cluster.h5"

change_dataframe_path = os.path.join(cluster_dir,file_name)

with pd.HDFStore(change_dataframe_path, 'r') as store:
    optimised_cluster_df = store.get("cluster")

# %%
cluster_dir = "../data/clusters/"
file_name = f"{article_name}_cluster.h5"
change_dataframe_path = os.path.join(cluster_dir,file_name)

with pd.HDFStore(change_dataframe_path, 'r') as store:
    cluster_df = store.get("cluster")

# %% [markdown]
# ##### Merging change object with its clusters

# %%
change_df_with_clusters = pd.concat([change_df, cluster_df], axis=1)
change_df_with_clusters["edited_tokens"] = change_df_with_clusters["ins_tokens"] + change_df_with_clusters["del_tokens"]


optimised_df_with_clusters = pd.concat([optimised_df, optimised_cluster_df], axis=1)
optimised_df_with_clusters["edited_tokens"] = optimised_df_with_clusters["ins_tokens"] + optimised_df_with_clusters["del_tokens"]

# %% [markdown]
# ## Finding relative positions of change object

# %%
content_dir = "../data/content/"
content_file = article_name + ".h5"
content_path = os.path.join(content_dir, content_file)
len_file = article_name + "_rev_len.h5"
len_file_path = os.path.join(content_dir, len_file)
rev_len_df = pd.read_hdf(len_file_path, key = "rev_len")

# rev_len_df = pd.DataFrame({"rev_id":rev_list[:-1], "length": rev_len_list[:-1]})


# with pd.HDFStore(content_path, 'r') as store:
#     #retrieving all rev list and change object from file
#     rev_list = store.get("rev_list")["id"].values.tolist()
#     keys = ["r" +  str(rev) for rev in rev_list]
#     rev_len_list = [store.get(key).shape[0] for key in keys]

# %%
rev_len_df.to_hdf(len_file_path, "rev_len")

# %%
optimised_df_with_clusters = optimised_df_with_clusters.reset_index().set_index('from revision id')
optimised_df_with_clusters = optimised_df_with_clusters.join(rev_len_df.set_index("rev_id"))
optimised_df_with_clusters.index.name = "from revision id"
optimised_df_with_clusters["relative_position"] =(optimised_df_with_clusters["left_neigh"]+1)/(optimised_df_with_clusters["length"])

# %%
# optimised_df_with_clusters["timestamp"] = optimised_df_with_clusters["timestamp"].astype('datetime64[ns]')
# optimised_df_with_clusters[["relative_position", "timestamp"]].plot()
# plt.yscale("log")
# plt.scatter(optimised_df_with_clusters["relative_position"],optimised_df_with_clusters[ "timestamp"])
# optimised_df_with_clusters[ "timestamp"]=pd.datetime(optimised_df_with_clusters["timestamp"])

# %%
plt.plot(optimised_df_with_clusters["timestamp"].astype('datetime64[ns]'),  optimised_df_with_clusters["relative_position"], linestyle="-")
plt.xscale("log")
plt.ylim([0,1])
# Out:
# (0, 1)

# %%
#optimised_df_with_clusters["cluster_4_backup"] = optimised_df_with_clusters["cluster_4"]
optimised_df_with_clusters["cluster_4"] = optimised_df_with_clusters["cluster_4_weighted"]
#optimised_df_with_clusters["cluster_4"] = optimised_df_with_clusters["cluster_4_backup"]

# %% [markdown]
# #### Grouping clusters and making html of each groups

# %%
# def find_freq_vocab_words( x, vocab):
#     freq = pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False)
#     return freq.loc[freq.index.intersection(vocab)]
# v = set(vocab)
# edited_tokens_freq_per_group = change_grouped_by_tokens["ins_tokens"].apply(lambda x: find_freq_vocab_words(x, v))
# left_context_freq_per_group = change_grouped_by_tokens["left_token"].apply(lambda x: find_freq_vocab_words(x, v))
# right_context_freq_per_group = change_grouped_by_tokens["right_token"].apply(lambda x: find_freq_vocab_words(x, v))
vocab_set = set(vocab)

# %%
optimised_df_with_clusters = optimised_df_with_clusters.reset_index().set_index(["from revision id","timestamp", "level_5"])


edited_tokens_freq_per_group = optimised_df_with_clusters.set_index("cluster_4")["edited_tokens"].apply(lambda tokens: tuple(token for token in tokens if token in vocab_set)).groupby("cluster_4").apply(lambda x:  pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False))
left_context_freq_per_group = optimised_df_with_clusters.set_index("cluster_4")["left_token"].apply(lambda tokens: tuple(token for token in tokens if token in vocab_set)).groupby("cluster_4").apply(lambda x:  pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False))
right_context_freq_per_group = optimised_df_with_clusters.set_index("cluster_4")["right_token"].apply(lambda tokens: tuple(token for token in tokens if token in vocab_set)).groupby("cluster_4").apply(lambda x:  pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False))

# %%
optimised_df_with_clusters["left_string"] = optimised_df_with_clusters["left_token"].apply(lambda tokens: tuple(token for token in tokens if token.isalnum())).str.join(" ")
optimised_df_with_clusters["del_string"] = optimised_df_with_clusters["ins_tokens"].apply(lambda tokens: tuple(token for token in tokens if token.isalnum())).str.join(" ")
optimised_df_with_clusters["ins_string"] = optimised_df_with_clusters["del_tokens"].apply(lambda tokens: tuple(token for token in tokens if token.isalnum())).str.join(" ")
optimised_df_with_clusters["right_string"] = optimised_df_with_clusters["right_token"].apply(lambda tokens: tuple(token for token in tokens if token.isalnum())).str.join(" ")

# change_df["left_string"] = change_df["left_token"].str.join(" ")
# change_df["ins_string"] = change_df["ins_tokens"].str.join(" ")
# change_df["del_string"] = change_df["del_tokens"].str.join(" ")
# change_df["right_string"] = change_df["right_token"].str.join(" ")

# %%
optimised_df_with_clusters = optimised_df_with_clusters.assign(counter_ts=optimised_df_with_clusters.groupby(["cluster_4","from revision id"]).ngroup() + 1)

# %%
#repers_weighted =  optimised_df_with_clusters.groupby("cluster_4")[["left_string", "del_string", "ins_string", "right_string"]].apply(lambda x: x.style.render())
repers_weighted =  optimised_df_with_clusters.reset_index().set_index("cluster_4")[["from revision id", "level_5", "counter_ts", "timestamp", "relative_position", "left_string", "del_string", "ins_string", "right_string"]]#.apply(lambda x: x.style.render())
optimised_df_with_clusters = optimised_df_with_clusters.reset_index().set_index(["from revision id", "level_5"])

change_grouped_by_tokens = optimised_df_with_clusters.groupby("cluster_4")

# %% [markdown]
# ### Ranking
# ###### Ranking clustered groups on following parameters.
# 1. Size of clusters
# 2. No of unique editors is clusters
# 3. Total period of cluster. i.e difference between start and end date.
# 4. Median length of edited token in each cluster.

# %%
rank_by_size = change_grouped_by_tokens.size().sort_values(ascending=False)

rank_by_uniq_editor = optimised_df_with_clusters.reset_index().groupby("cluster_4")["editor"].nunique().sort_values(ascending=False)

rank_by_period = optimised_df_with_clusters.reset_index().groupby("cluster_4")["timestamp"].apply(lambda x: x.max() - x.min()).sort_values(ascending=False)

rank_by_rate = optimised_df_with_clusters.reset_index().groupby("cluster_4")["timegap"].apply(lambda x: x.mean()).sort_values(ascending=False)

# unique_word_count_per_group = word_freq_per_group.groupby("cluster_4_weighted").apply(lambda x: x.index.shape[0]).sort_values(ascending=False)

# %% [markdown]
# ## Visualisation for change object clustered on neighbour vectors
#
# Following visualisation can be used to compare with above visualisation which is using neighbour vectors to cluster.

# %%
count = 100
def plot_freq(gap_freq, left_context_freq, right_context_freq, timestamp, relative_position, number=100):
    fig, axs = plt.subplots(nrows=1, ncols=3,figsize=(35, 20))
        
    axs[0].barh( left_context_freq.index[:count][::-1], left_context_freq.values[:count][::-1])
    axs[0].set_title(" frequency plot of top 100 words in left context")
    axs[0].set_xlabel("frequency")
    axs[0].set_ylabel("unique words in left context ")
    
    axs[1].barh( gap_freq.index[:count][::-1], gap_freq.values[:count][::-1])
    axs[1].set_title(" frequency plot of top 100 words in gap")
    axs[1].set_xlabel("frequency")
    axs[1].set_ylabel("unique words in gap ")
    
    axs[2].barh( right_context_freq.index[:count][::-1], right_context_freq.values[:count][::-1])
    axs[2].set_title(" frequency plot of top 100 words in right context")
    axs[2].set_xlabel("frequency")
    axs[2].set_ylabel("unique words in right context ")
    
    fig2, ax = plt.subplots(nrows=1, ncols=1,figsize=(35, 20))
    ax.scatter( timestamp, relative_position, c="red",marker="D", label = "relative position with respect to timestamp")
    ax.set_title(" Plot of timestamp with relative position")
    ax.set_xlabel("timestamp")
    ax.set_ylabel("relative position ")
    plt.ylim(0, 1)
    ax.legend()
#     axs[3].set_xscale("log")
#     axs[3].set_yscale("log")


    return fig
# _= plot_freq(edited_tokens_freq_per_group.loc[1], 
#             left_context_freq_per_group.loc[1], 
#             right_context_freq_per_group.loc[1],
#             change_grouped_by_tokens["timestamp"].get_group(2).values,
#             change_grouped_by_tokens["relative_position"].get_group(2).values
#             )

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

def display_article_content(index, change_html_series, edited_tokens_freq_per_group, left_context_freq_per_group, right_context_freq_per_group, change_grouped_by_tokens, out):
    global change_html_glob
    with out:
        out.clear_output()
        
    change_html = change_html_series.loc[index]
    
    change_html_glob = change_html
    _ = plot_freq(edited_tokens_freq_per_group.loc[index], 
            left_context_freq_per_group.loc[index], 
            right_context_freq_per_group.loc[index],
            change_grouped_by_tokens["counter_ts"].get_group(index).values,
            change_grouped_by_tokens["relative_position"].get_group(index).values)
    with out:
#         display(change_html)
        display(f"Word length distribution for {index}")
#         display(fig)
        display(change_html.set_index(["from revision id", "level_5", "timestamp", "counter_ts", "relative_position"]))
        #display(HTML(change_html))
#     return out

# %%
drop_down = list(zip(np.arange(rank_by_period.size), rank_by_period.index))

# %% [markdown]
# **Please rerun next cell each time page is reloaded**

# %%
outp = widgets.Output(layout={'border': '1px solid black'})

_=widgets.interact(display_article_content, index=drop_down, change_html_series= widgets.fixed(repers_weighted),edited_tokens_freq_per_group= widgets.fixed(edited_tokens_freq_per_group), left_context_freq_per_group= widgets.fixed(left_context_freq_per_group), right_context_freq_per_group= widgets.fixed(right_context_freq_per_group), change_grouped_by_tokens= widgets.fixed(change_grouped_by_tokens), out=widgets.fixed(outp));
# Out:
# interactive(children=(Dropdown(description='index', options=((0, 26), (1, 85), (2, 89), (3, 45), (4, 62), (5, …

# %%
#outp
change_html_glob.set_index(["from revision id", "level_5", "timestamp", "counter_ts", "relative_position"])
# Out:
#                                                                                                                                                                                                                                          left_string  \
# from revision id level_5 timestamp           counter_ts relative_position
# 286436           1       2001-03-21 00:36:45 2083       0.001885           the following is a portion of
# 440545           23      2002-11-23 11:57:29 2084       0.335232           the original version of this bare bones theory is called the redundancy theory of truth and it is due to f p ramsey
#                  24      2002-11-23 11:57:29 2084       0.335842           original version of this bare bones theory is called the redundancy theory of truth and it is due to f p ramsey an english
# 442894           20      2002-11-24 18:48:03 2085       0.995692           to rest content with any sort of relativism that says that truth is just the same as belief you can do a heck of a lot better than that
# 928657           4       2003-05-17 04:02:07 2086       0.406340           millions of stillborns are promulgating and proselytizing iggiation ignorance of the truth the fundamental truth is being raped by the ignorant ignorance will not
#                  6       2003-05-17 04:02:07 2086       0.582133           an intelligent woman you must join the fight for truth please search deep within and internalize the fear and agony that the reign of the stillborn will instill upon
#                  8       2003-05-17 04:02:07 2086       0.737752           catch cry packs of lies exist to lead us astray placed by the ignorant join the righteous fight for truth remember truth is
#                  16      2003-05-17 04:02:07 2086       0.902017           www sids org uk fsid bartlett jpg i your future leader i
#                  24      2003-05-17 04:02:07 2086       0.994236           click the below link for further information including an opportunity to obtain a free brochure on instilling truth in this nation thank you for your time
# 1096787          51      2003-06-30 17:21:18 2087       0.936396           at once with the post facto nature of symbolic description and the choice a community has in explaining its motives before the fact and after the fact
# 1096868          41      2003-06-30 17:59:44 2088       0.884974           the minds of people long dead or facts about very distant events perhaps there are facts about subatomic particles which we cannot in principle ever know
# 1305011          13      2003-08-17 22:32:56 2089       0.053374           any special insight one generally commits oneself to truth of this kind and does not question it further this we may call the authoritative type of truth
# 1591195          22      2003-10-19 16:30:33 2090       0.225327           one of the first four headings where you see some assertion that propaganda or authority is being over trusted it is likely that the
#                  34      2003-10-19 16:30:33 2090       0.644440           to some standard of evidence for some period of time thoughtful people may think of this kind of truth as something that holds for a
#                  72      2003-10-19 16:30:33 2090       0.225043           will fall under one of the first four headings where you see some assertion that propaganda or authority is being over trusted it is
# 1614005          27      2003-10-24 00:10:39 2091       0.367849           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
# 1635251          153     2003-10-27 21:37:12 2092       0.716235           were introduced by the american philosophers charles peirce pronounced purse and william james in the late 19th and early 20th centuries
#                  250     2003-10-27 21:37:12 2092       0.335798           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
# 1643161          25      2003-10-29 12:51:18 2093       0.154278           under the heading of truth but instead moral absolutism relativism realism anti realism and various other headings
#                  88      2003-10-29 12:51:18 2093       0.400000           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
#                  136     2003-10-29 12:51:18 2093       0.643882           to some standard of evidence for some period of time thoughtful people may think of this kind of truth as something that holds for a
#                  186     2003-10-29 12:51:18 2093       0.787580           limit of inquiry in that way pragmatism is very optimistic it is also necessarily a route to scientism two basic objections are commonly made to
# 1643275          214     2003-10-29 13:12:49 2094       0.335798           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
# 1643325          25      2003-10-29 13:22:54 2095       0.226163           under the heading of truth but instead moral absolutism relativism realism anti realism and various other headings
#                  88      2003-10-29 13:22:54 2095       0.586379           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
#                  136     2003-10-29 13:22:54 2095       0.943898           to some standard of evidence for some period of time thoughtful people may think of this kind of truth as something that holds for a
# 1644686          0       2003-10-29 20:05:42 2096       0.057619           by the decision of the question what is truth we see below that the epistemic theories of truth involve questions concerning the subject me
# 1653418          13      2003-10-31 16:47:17 2097       0.026221           such a state of affairs that it is the case as aristotle put it in his metaphysics book 4
#                  203     2003-10-31 16:47:17 2097       0.331355           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
# 1653461          92      2003-10-31 16:57:15 2098       0.400000           or deflationism for short deflationism has two major versions a version called i minimalism i which has been developed by paul horwich
# ...                                                                                                                                                                                                           ...
# 696819512        0       2015-12-30 07:11:37 2467       0.000247           other uses
# 697398822        0       2015-12-30 07:12:08 2468       0.000247           other uses
# 702053200        0       2016-01-31 07:59:29 2469       0.000590           other uses pp move indef
# 704181566        2       2016-02-27 22:36:25 2470       0.253344           p 718 column 1 and ending on p 720 with the initials c s p see google books
# 711977070        0       2016-03-26 03:20:03 2471       0.003090           someone with stupendously comprehensive knowledge of goo gl jmqwiw might want to help organize the structure of the related articles truth justification meaning ontology
# 735166796        2       2016-09-11 19:31:02 2472       0.004902           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 742749833        0       2016-11-02 06:14:14 2473       0.082500           perhaps ultimately from pie dru tree on the notion of steadfast as an oak e g sanskrit
# 747926289        10      2016-11-11 11:52:59 2474       0.066064           anchor treowe certainty sidebar file an angel carrying the banner of truth roslin midlothian jpg thumb
#                  11      2016-11-11 11:52:59 2474       0.066650           an angel carrying the banner of truth roslin midlothian jpg thumb 300px an angel carrying the banner of truth
# 786200049        2       2017-06-22 23:54:12 2475       0.401029           surveys results pl affil all respondents areas0 0 areas max 1 grain medium title the philpapers surveys
# 787037420        0       2017-06-23 01:59:04 2476       0.539518           o pusan sun so that i who have truth as my duty satyadharma may see it brhadaranyaka v 15 1
# 787208991        2       2017-06-24 03:09:14 2477       0.525876           in terms of a thought s likeness to a thing or fact it is clear that such a definition would fit well into his overall philosophy of mind
#                  3       2017-06-24 03:09:14 2477       0.526070           thought s likeness to a thing or fact it is clear that such a definition would fit well into his overall philosophy of mind
#                  15      2017-06-24 03:09:14 2477       0.793766           see also portal thinking wikipedia books epistemology div col cols 3 theory of justification
#                  26      2017-06-24 03:09:14 2477       0.548840           of healing book i chapter 8 as quote what corresponds in the mind to what is outside it
#                  28      2017-06-24 03:09:14 2477       0.553112           chapter 6 quote the truth of a thing is the property of the being of each thing which has been established in it
#                  32      2017-06-24 03:09:14 2477       0.627003           him as witness is an honest man the accusation was grounded too only the solution of the indicated problem is impossible without qualification and for every man
# 790032226        5       2017-07-11 04:56:36 2478       0.021475           other philosophers take this common meaning to be secondary and derivative according to martin heidegger the original meaning and essence of truth
#                  8       2017-07-11 04:56:36 2478       0.069318           via google books ref definition and etymology further veritas aletheia tryggvi anchor treowe
# 792095354        3       2017-07-27 13:29:40 2479       0.673777           the forms space time causality of intuitive empirical knowledge then the judgment has transcendental truth kierkegaard
# 792599547        5       2017-07-27 14:29:24 2480       0.673122           space time causality of intuitive empirical knowledge then the judgment has transcendental truth kierkegaard 1813
#                  11      2017-07-27 14:29:24 2480       0.743561           and that increasing interaction between cultures allows for these aspects to reconcile and integrate increasing further the approximation to the truth foucault 1926
# 809358052        0       2017-11-19 20:19:23 2481       0.805725           record good and bad deeds ref see also portal thinking wikipedia books epistemology div col
# 820015544        0       2018-01-16 01:27:12 2482       0.804399           record good and bad deeds ref see also portal thinking wikipedia books epistemology div col
# 824455538        0       2018-02-08 00:33:14 2483       0.000708           other uses pp move indef certainty
# 824547013        0       2018-02-08 00:35:26 2484       0.000708           other uses pp move indef certainty
# 837254254        2       2018-04-19 17:32:05 2485       0.106543           pmc editor2 last wright title a companion to the philosophy of language ref however the substantive theories are
# 845108806        2       2018-06-20 19:38:04 2486       0.427806           human and then are somewhere in what sphere we know not rather truth is disclosure of beings through which an openness essentially unfolds
# 858176005        13      2018-09-08 02:58:22 2487       0.391358           ref in general the concept of representing truth using more than two values is known as many valued logic ref cite book
#                  15      2018-09-08 02:58:22 2487       0.507290           kevin title replacing truth date 2013 publisher oxford univ press location oxford isbn 978 0199653850 edition first
#
#                                                                                                                                                         del_string  \
# from revision id level_5 timestamp           counter_ts relative_position
# 286436           1       2001-03-21 00:36:45 2083       0.001885           foregoing
# 440545           23      2002-11-23 11:57:29 2084       0.335232           and alfred ayer
#                  24      2002-11-23 11:57:29 2084       0.335842           philosophers
# 442894           20      2002-11-24 18:48:03 2085       0.995692           references 1 kirkham richard 1992
# 928657           4       2003-05-17 04:02:07 2086       0.406340           amenable
#                  6       2003-05-17 04:02:07 2086       0.582133           definition
#                  8       2003-05-17 04:02:07 2086       0.737752           the subject of much theorizing by philosophers and by thinkers
#                  16      2003-05-17 04:02:07 2086       0.902017           by almost all contemporary philosophers and logicians see
#                  24      2003-05-17 04:02:07 2086       0.994236           that the streetlights turn on
# 1096787          51      2003-06-30 17:21:18 2087       0.936396
# 1096868          41      2003-06-30 17:59:44 2088       0.884974           is that
# 1305011          13      2003-08-17 22:32:56 2089       0.053374           view although in theory artificial intelligence or collective intelligence for instance
# 1591195          22      2003-10-19 16:30:33 2090       0.225327           i correspondence conception i that
#                  34      2003-10-19 16:30:33 2090       0.644440           perspective
#                  72      2003-10-19 16:30:33 2090       0.225043
# 1614005          27      2003-10-24 00:10:39 2091       0.367849           see horwich 1998 i truth i
# 1635251          153     2003-10-27 21:37:12 2092       0.716235           i
#                  250     2003-10-27 21:37:12 2092       0.335798
# 1643161          25      2003-10-29 12:51:18 2093       0.154278           only
#                  88      2003-10-29 12:51:18 2093       0.400000           see horwich 1998 i truth i
#                  136     2003-10-29 12:51:18 2093       0.643882           perspective
#                  186     2003-10-29 12:51:18 2093       0.787580           sceptical
# 1643275          214     2003-10-29 13:12:49 2094       0.335798
# 1643325          25      2003-10-29 13:22:54 2095       0.226163           whether a truth bearer is true
#                  88      2003-10-29 13:22:54 2095       0.586379
#                  136     2003-10-29 13:22:54 2095       0.943898           confused people
# 1644686          0       2003-10-29 20:05:42 2096       0.057619           we they
# 1653418          13      2003-10-31 16:47:17 2097       0.026221           particular religion or devotional practice and it is also difficult to claim any
#                  203     2003-10-31 16:47:17 2097       0.331355
# 1653461          92      2003-10-31 16:57:15 2098       0.400000           see horwich 1998 i truth i
# ...                                                                       ..
# 696819512        0       2015-12-30 07:11:37 2467       0.000247           a 540 is truth
# 697398822        0       2015-12-30 07:12:08 2468       0.000247           pp move indef
# 702053200        0       2016-01-31 07:59:29 2469       0.000590           certainty
# 704181566        2       2016-02-27 22:36:25 2470       0.253344           https
# 711977070        0       2016-03-26 03:20:03 2471       0.003090           date march 2016
# 735166796        2       2016-09-11 19:31:02 2472       0.004902           proposition
# 742749833        0       2016-11-02 06:14:14 2473       0.082500           taru
# 747926289        10      2016-11-11 11:52:59 2474       0.066064           left
#                  11      2016-11-11 11:52:59 2474       0.066650
# 786200049        2       2017-06-22 23:54:12 2475       0.401029
# 787037420        0       2017-06-23 01:59:04 2476       0.539518
# 787208991        2       2017-06-24 03:09:14 2477       0.525876
#                  3       2017-06-24 03:09:14 2477       0.526070
#                  15      2017-06-24 03:09:14 2477       0.793766           degree of truth
#                  26      2017-06-24 03:09:14 2477       0.548840
#                  28      2017-06-24 03:09:14 2477       0.553112
#                  32      2017-06-24 03:09:14 2477       0.627003
# 790032226        5       2017-07-11 04:56:36 2478       0.021475
#                  8       2017-07-11 04:56:36 2478       0.069318
# 792095354        3       2017-07-27 13:29:40 2479       0.673777           1813 1855
# 792599547        5       2017-07-27 14:29:24 2480       0.673122
#                  11      2017-07-27 14:29:24 2480       0.743561
# 809358052        0       2017-11-19 20:19:23 2481       0.805725           15em
# 820015544        0       2018-01-16 01:27:12 2482       0.804399           colwidth
# 824455538        0       2018-02-08 00:33:14 2483       0.000708           1111
# 824547013        0       2018-02-08 00:35:26 2484       0.000708
# 837254254        2       2018-04-19 17:32:05 2485       0.106543           also discussed
# 845108806        2       2018-06-20 19:38:04 2486       0.427806
# 858176005        13      2018-09-08 02:58:22 2487       0.391358
#                  15      2018-09-08 02:58:22 2487       0.507290
#
#                                                                                                                                 ins_string  \
# from revision id level_5 timestamp           counter_ts relative_position
# 286436           1       2001-03-21 00:36:45 2083       0.001885
# 440545           23      2002-11-23 11:57:29 2084       0.335232           an
#                  24      2002-11-23 11:57:29 2084       0.335842           philosopher
# 442894           20      2002-11-24 18:48:03 2085       0.995692
# 928657           4       2003-05-17 04:02:07 2086       0.406340           lead
#                  6       2003-05-17 04:02:07 2086       0.582133           you and your neighbor fight
#                  8       2003-05-17 04:02:07 2086       0.737752           our call watch all but trust none may truth evermore reign
#                  16      2003-05-17 04:02:07 2086       0.902017           click the
#                  24      2003-05-17 04:02:07 2086       0.994236
# 1096787          51      2003-06-30 17:21:18 2087       0.936396           philosophy
# 1096868          41      2003-06-30 17:59:44 2088       0.884974           here s
# 1305011          13      2003-08-17 22:32:56 2089       0.053374
# 1591195          22      2003-10-19 16:30:33 2090       0.225327           fifth concept
#                  34      2003-10-19 16:30:33 2090       0.644440           lifetime or some equivalently long but more standardized period
#                  72      2003-10-19 16:30:33 2090       0.225043           likely that
# 1614005          27      2003-10-24 00:10:39 2091       0.367849
# 1635251          153     2003-10-27 21:37:12 2092       0.716235
#                  250     2003-10-27 21:37:12 2092       0.335798           see horwich 1998 i truth i
# 1643161          25      2003-10-29 12:51:18 2093       0.154278
#                  88      2003-10-29 12:51:18 2093       0.400000
#                  136     2003-10-29 12:51:18 2093       0.643882           lifetime or some equivalently long but more standardized period
#                  186     2003-10-29 12:51:18 2093       0.787580           pragmatism
# 1643275          214     2003-10-29 13:12:49 2094       0.335798           see horwich 1998 i truth i
# 1643325          25      2003-10-29 13:22:54 2095       0.226163
#                  88      2003-10-29 13:22:54 2095       0.586379
#                  136     2003-10-29 13:22:54 2095       0.943898           lifetime or some equivalently long but more standardized period
# 1644686          0       2003-10-29 20:05:42 2096       0.057619
# 1653418          13      2003-10-31 16:47:17 2097       0.026221
#                  203     2003-10-31 16:47:17 2097       0.331355           see horwich 1998 i truth i
# 1653461          92      2003-10-31 16:57:15 2098       0.400000
# ...                                                                                               ...
# 696819512        0       2015-12-30 07:11:37 2467       0.000247           pp move indef
# 697398822        0       2015-12-30 07:12:08 2468       0.000247           a 540 is truth
# 702053200        0       2016-01-31 07:59:29 2469       0.000590
# 704181566        2       2016-02-27 22:36:25 2470       0.253344           http
# 711977070        0       2016-03-26 03:20:03 2471       0.003090
# 735166796        2       2016-09-11 19:31:02 2472       0.004902           françois lemoyne
# 742749833        0       2016-11-02 06:14:14 2473       0.082500           dru
# 747926289        10      2016-11-11 11:52:59 2474       0.066064           300px
#                  11      2016-11-11 11:52:59 2474       0.066650
# 786200049        2       2017-06-22 23:54:12 2475       0.401029
# 787037420        0       2017-06-23 01:59:04 2476       0.539518
# 787208991        2       2017-06-24 03:09:14 2477       0.525876
#                  3       2017-06-24 03:09:14 2477       0.526070
#                  15      2017-06-24 03:09:14 2477       0.793766           aletheia
#                  26      2017-06-24 03:09:14 2477       0.548840
#                  28      2017-06-24 03:09:14 2477       0.553112
#                  32      2017-06-24 03:09:14 2477       0.627003
# 790032226        5       2017-07-11 04:56:36 2478       0.021475
#                  8       2017-07-11 04:56:36 2478       0.069318           certainty sidebar
# 792095354        3       2017-07-27 13:29:40 2479       0.673777
# 792599547        5       2017-07-27 14:29:24 2480       0.673122
#                  11      2017-07-27 14:29:24 2480       0.743561
# 809358052        0       2017-11-19 20:19:23 2481       0.805725           cols 3
# 820015544        0       2018-01-16 01:27:12 2482       0.804399
# 824455538        0       2018-02-08 00:33:14 2483       0.000708
# 824547013        0       2018-02-08 00:35:26 2484       0.000708           1111
# 837254254        2       2018-04-19 17:32:05 2485       0.106543           not universally accepted
# 845108806        2       2018-06-20 19:38:04 2486       0.427806           i
# 858176005        13      2018-09-08 02:58:22 2487       0.391358           work topics in philosophical logic
#                  15      2018-09-08 02:58:22 2487       0.507290           edition
#
#                                                                                                                                                                                                                                                            right_string
# from revision id level_5 timestamp           counter_ts relative_position
# 286436           1       2001-03-21 00:36:45 2083       0.001885           is a portion of larrystext wikification is encouraged what is truth we ll look at a number of answers to this question that philosophers have given
# 440545           23      2002-11-23 11:57:29 2084       0.335232           english philosopher who lived about the same time as moore and russell it s called the redundancy theory because it basically implies that saying that something is
#                  24      2002-11-23 11:57:29 2084       0.335842           who lived about the same time as moore and russell it s called the redundancy theory because it basically implies that saying that something is true is
# 442894           20      2002-11-24 18:48:03 2085       0.995692           good reference book kirkham richard 1992 i theories of truth i bradford books
# 928657           4       2003-05-17 04:02:07 2086       0.406340           to salvation but will only lead to our perpetual slavery to the stillborn we must fight the occupation now friend you are obviously an intelligent
#                  6       2003-05-17 04:02:07 2086       0.582133           trust no one trust only those proselytizing truth truth must be our catch cry packs of lies exist to lead us astray placed by the
#                  8       2003-05-17 04:02:07 2086       0.737752           in our hearts img src http www sids org uk fsid bartlett jpg
#                  16      2003-05-17 04:02:07 2086       0.902017           below link for further information including an opportunity to obtain a free brochure on instilling truth in this nation thank you for your time
#                  24      2003-05-17 04:02:07 2086       0.994236
# 1096787          51      2003-06-30 17:21:18 2087       0.936396           after this very brief discussion of theories of truth we note that contemporary philosophers tend to favor either some revised correspondence theory or some deflationary theory but we just
# 1096868          41      2003-06-30 17:59:44 2088       0.884974           a second objection due originally to bertrand russell basically what pragmatism describes an i indicator i or a i sign
# 1305011          13      2003-08-17 22:32:56 2089       0.053374           and third there is truth as a body of important profound perhaps spiritual belief truth with a capital t or enlightenment
# 1591195          22      2003-10-19 16:30:33 2090       0.225327           is in play almost all of the most common attempts to define truth fall under the epistemic conception which paradoxically is the one i rejected
#                  34      2003-10-19 16:30:33 2090       0.644440           e g to the seventh generation however no matter how long a time horizon is chosen and despite the popularity of this theory
#                  72      2003-10-19 16:30:33 2090       0.225043           the fifth concept is in play almost all of the most common attempts to define truth fall under the epistemic conception which paradoxically is the one
# 1614005          27      2003-10-24 00:10:39 2091       0.367849           and a version called i disquotationalism i which has been developed by hartry field the minimalist theory takes truth bearers to be
# 1635251          153     2003-10-27 21:37:12 2092       0.716235           in the late 19th and early 20th centuries peirce s theory is called i long run pragmatism i william james s theory
#                  250     2003-10-27 21:37:12 2092       0.335798           and a version called i disquotationalism i which has been developed by hartry field see field 2001 i truth and the
# 1643161          25      2003-10-29 12:51:18 2093       0.154278           not specifically under the heading of truth but instead moral absolutism relativism realism anti realism and various other
#                  88      2003-10-29 12:51:18 2093       0.400000           and a version called i disquotationalism i which has been developed by hartry field the minimalist theory takes truth bearers to be
#                  136     2003-10-29 12:51:18 2093       0.643882           e g to the seventh generation however no matter how long a time horizon is chosen and despite the popularity of this theory
#                  186     2003-10-29 12:51:18 2093       0.787580           first a common objection of theologians and skeptics both you can say maybe there are some truths that i aren 8217 t
# 1643275          214     2003-10-29 13:12:49 2094       0.335798           and a version called i disquotationalism i which has been developed by hartry field see field 2001 i truth and the
# 1643325          25      2003-10-29 13:22:54 2095       0.226163           not specifically under the heading of truth but instead moral absolutism relativism realism anti realism and various other
#                  88      2003-10-29 13:22:54 2095       0.586379           and a version called i disquotationalism i which has been developed by hartry field the minimalist theory takes truth bearers to be
#                  136     2003-10-29 13:22:54 2095       0.943898           e g to the seventh generation however no matter how long a time horizon is chosen and despite the popularity of this theory
# 1644686          0       2003-10-29 20:05:42 2096       0.057619           and the state of affairs concerning which i for example may make statements which are either true or not true
# 1653418          13      2003-10-31 16:47:17 2097       0.026221           special class of questions that can be asked about truth concern whether this property is objective roughly whether a truth bearer is true depends on the facts of reality
#                  203     2003-10-31 16:47:17 2097       0.331355           and a version called i disquotationalism i which has been developed by hartry field see field 2001 i truth and the
# 1653461          92      2003-10-31 16:57:15 2098       0.400000           and a version called i disquotationalism i which has been developed by hartry field the minimalist theory takes truth bearers to be
# ...                                                                                                                                                                                       ...
# 696819512        0       2015-12-30 07:11:37 2467       0.000247           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 697398822        0       2015-12-30 07:12:08 2468       0.000247           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 702053200        0       2016-01-31 07:59:29 2469       0.000590           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 704181566        2       2016-02-27 22:36:25 2470       0.253344           books google com books id dc8yaaaaiaaj pg pa718 eprint reprinted charles sanders peirce bibliography
# 711977070        0       2016-03-26 03:20:03 2471       0.003090           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 735166796        2       2016-09-11 19:31:02 2472       0.004902           1737 file truth warner highsmith jpeg thumb truth holding a mirror and a serpent symbolism
# 742749833        0       2016-11-02 06:14:14 2473       0.082500           tree ref name truth from online etymology cite web last etymology first online title online etymology
# 747926289        10      2016-11-11 11:52:59 2474       0.066064           an angel carrying the banner of truth roslin midlothian the english word wikt truth truth is
#                  11      2016-11-11 11:52:59 2474       0.066650           roslin midlothian the english word wikt truth truth is derived from old english tríewþ tréowþ
# 786200049        2       2017-06-22 23:54:12 2475       0.401029           preliminary survey results work the philpapers surveys publisher philpapers org date accessdate 2012 05 27 ref
# 787037420        0       2017-06-23 01:59:04 2476       0.539518           4 and the brief iisa upanisad 15 18 truth is superior to silence manusmriti etc combined with other words satya acts
# 787208991        2       2017-06-24 03:09:14 2477       0.525876           ref name stanfordcorr blockquote very similar statements can also be found in plato cratylus 385b2
#                  3       2017-06-24 03:09:14 2477       0.526070           ref name stanfordcorr blockquote very similar statements can also be found in plato cratylus 385b2 sophist 263b ref name
#                  15      2017-06-24 03:09:14 2477       0.793766           asha belief confirmation holism contextualism contradiction degrees of truth disposition
#                  26      2017-06-24 03:09:14 2477       0.548840           ref osman amin 2007 influence of muslim philosophy on the west monthly renaissance 17
#                  28      2017-06-24 03:09:14 2477       0.553112           ref name aertsen jan a aertsen 1988 nature and creature thomas aquinas s way of thought p
#                  32      2017-06-24 03:09:14 2477       0.627003           ref name kant 1801 kant immanuel 1801 the jäsche logic in
# 790032226        5       2017-07-11 04:56:36 2478       0.021475           in ancient greece was unconcealment or the revealing or bringing of what was previously hidden into the open as indicated by the original greek term for truth
#                  8       2017-07-11 04:56:36 2478       0.069318           file an angel carrying the banner of truth roslin midlothian jpg thumb left an angel carrying the banner of truth
# 792095354        3       2017-07-27 13:29:40 2479       0.673777           when søren kierkegaard as his character johannes climacus ends his writings my thesis was subjectivity
# 792599547        5       2017-07-27 14:29:24 2480       0.673122           1855 when søren kierkegaard as his character johannes climacus ends his writings my thesis was
#                  11      2017-07-27 14:29:24 2480       0.743561           1984 file what is truth02 jpg thumb john 18 38 quod est veritas
# 809358052        0       2017-11-19 20:19:23 2481       0.805725           asha belief confirmation holism contextualism contradiction degree of truth disposition
# 820015544        0       2018-01-16 01:27:12 2482       0.804399           15em asha belief confirmation holism contextualism contradiction degree of truth
# 824455538        0       2018-02-08 00:33:14 2483       0.000708           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 824547013        0       2018-02-08 00:35:26 2484       0.000708           file time saving truth from falsehood and envy jpg thumb time saving truth from falsehood and envy
# 837254254        2       2018-04-19 17:32:05 2485       0.106543           more recently developed deflationary theory of truth deflationary or minimalist theories of truth have emerged as competitors to the older substantive theories
# 845108806        2       2018-06-20 19:38:04 2486       0.427806           west i ref cite book last heidegger first martin title on the essence of truth year
# 858176005        13      2018-09-08 02:58:22 2487       0.391358           last rescher first nicholas publisher humanities press synthese library volume 17 year 1968 title many valued logic url
#                  15      2018-09-08 02:58:22 2487       0.507290           chapter 6 what is the use ref individuals or societies will sometime punish false statements to deter falsehoods ref
#
# [949 rows x 4 columns]

# %%
# widgets.Dropdown(
#     options=['1', '2', '3'],
#     value='2',
#     description='Number:',
#     disabled=False,
# )

# %% [markdown]
# ### **Bykau Et. al.** change objects and its clusters

# %%
bykau_dir =  "../data/bykau_change_object/"
filename =  f"{article_name}_change.h5"

change_object_file = os.path.join(bykau_dir, filename)
bykau_change_df = pd.read_hdf(change_object_file, key="data")
bykau_change_df.shape

# %%
bykau_change_df = bykau_change_df.reset_index().set_index('from revision id')
bykau_change_df = bykau_change_df.join(rev_len_df.set_index("rev_id"))
bykau_change_df.index.name = "from revision id"
bykau_change_df["relative_position"] =(bykau_change_df["left_neigh"]+1)/(bykau_change_df["length"])

# %%
bykau_change_df["left_string"] = bykau_change_df["left_token"].str.join(" ")
bykau_change_df["ins_string"] = bykau_change_df["ins_tokens"].str.join(" ")
bykau_change_df["del_string"] = bykau_change_df["del_tokens"].str.join(" ")
bykau_change_df["right_string"] = bykau_change_df["right_token"].str.join(" ")

# %% [markdown]
# #### Grouping and ranking.

# %%
bykau_groups = bykau_change_df.groupby("reclustered_group")

# bykau_edited_freq = bykau_groups["ins_tokens"].apply(lambda x: find_freq_vocab_words(x, vocab))
# bykau_left_context_freq = bykau_groups["left_token"].apply(lambda x: find_freq_vocab_words(x, vocab))
# bykau_right_context_freq = bykau_groups["right_token"].apply(lambda x: find_freq_vocab_words(x, vocab))

bykau_edited_freq = bykau_groups["ins_tokens"].apply(lambda x:  pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False))
bykau_left_context_freq = bykau_groups["left_token"].apply(lambda x:  pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False))
bykau_right_context_freq = bykau_groups["right_token"].apply(lambda x:  pd.Series(np.concatenate(x.values, axis=0)).value_counts(ascending=False))

# %%
bykau_rank_by_size = bykau_groups.size().sort_values(ascending=False)

bykau_rank_by_uniq_editor = bykau_change_df.reset_index().groupby("reclustered_group")["editor"].nunique().sort_values(ascending=False)

bykau_rank_by_period = bykau_change_df.reset_index().groupby("reclustered_group")["timestamp"].apply(lambda x: x.max() - x.min()).sort_values(ascending=False)

bykau_rank_by_rate = bykau_change_df.reset_index().groupby("reclustered_group")["timegap"].apply(lambda x: x.mean()).sort_values(ascending=False)

bykau_change_df = bykau_change_df.reset_index().set_index(["from revision id", "level_5"])


# unique_word_count_per_group = word_freq_per_group.groupby("cluster_4_weighted").apply(lambda x: x.index.shape[0]).sort_values(ascending=False)

# %% [markdown]
# #### Bykau Visualisation
#
# THis can be used to compare with our visualisation.

# %%
bykau_drop_down = list(zip(np.arange(bykau_rank_by_period.size), bykau_rank_by_period.index))

# %%
repers_bykau = bykau_change_df.groupby("reclustered_group")[["left_string", "del_string", "ins_string", "right_string"]].apply(lambda x: x.style.render())

# %% [markdown]
# **Please rerun next cell each time page is reloaded**

# %%
bykau_outp = widgets.Output(layout={'border': '1px solid black'})

# _=widgets.interact(display_article_content, index=drop_down, change_html_series= widgets.fixed(repers_bykau), out=widgets.fixed(bykau_outp));

_=widgets.interact(display_article_content, index=bykau_drop_down, change_html_series= widgets.fixed(repers_bykau),edited_tokens_freq_per_group= widgets.fixed(bykau_edited_freq), left_context_freq_per_group= widgets.fixed(bykau_left_context_freq), right_context_freq_per_group= widgets.fixed(bykau_right_context_freq), change_grouped_by_tokens= widgets.fixed(bykau_change_df.groupby("reclustered_group")), out=widgets.fixed(bykau_outp));

# %%
bykau_outp

# %%
# @interact( clusters_html=fixed(repers_4_neigh), group=range(groups.ngroups))
# def display_clusters(clusters_html, group):
#      return display(HTML(clusters_html.iloc[group]))

# %%
# drop_down = list(zip(rev_list.id, rev_list.index))
