# %%
import gensim
from gensim.models import KeyedVectors
from gensim.models.fasttext import FastText as FT_gensim
import pandas as pd
import numpy as np
import requests
import pickle
import os

# %%
# FT_gensim.load('../wordvectors/wiki-news-300d-1M-subword.vec.zip')
wiki_vec = KeyedVectors.load_word2vec_format('../wordvectors/wiki.en.vec', binary=False, limit=5000)
vocab = set(wiki_vec.vocab)

# %%
class Wiki:
    def __init__(self,id,title, all_tokens=[]):
        self.id = id
        self.title = title
        self.all_tokens = all_tokens
        
    def init_revisions(self, revisions):
#         self.revisions = {revision["id"] : Revision(revision["id"],revision["timestamp"], revision["editor"]) for revision in revisions}
          self.revisions = pd.Series( {revision["id"] : 
                                       Revision(revision["id"],revision["timestamp"], revision["editor"]) for revision in revisions} )

 
    def add_all_token(self, all_tokens):
        self.all_tokens = all_tokens
        for token in self.all_tokens:
            self.revisions.loc[token["o_rev_id"]].added.add(token["token_id"])
            for in_revision in token["in"]:
                self.revisions.loc[in_revision].added.add(token["token_id"])
            for out_revision in token["out"]:
                self.revisions.loc[out_revision].removed.add(token["token_id"])
class Revision:
    def __init__(self, id, timestamp,editor):
        self.id = id
        self.timestamp = timestamp
        self.editor = editor
        self.added = set()
        self.removed = set()   
        
    def deleted(self, to_rev):
        self.content["removed"] = pd.Series(np.isin( self.content["token_id"].values, list(t_rev.removed), assume_unique= True ))
        end_pos = np.argwhere(np.ediff1d(np.pad(self.content["removed"].astype(np.int), (1,1), mode="constant", constant_values=0)) == -1) -1 
        start_pos = np.argwhere(np.ediff1d(np.pad(self.content["removed"].astype(np.int), (1,1), mode="constant", constant_values=0)) == 1)
        start_neighbour = start_pos - 1
        end_neighbour = end_pos + 1
#         self.first_last_token_del = self.content["removed"].values[[0,-1]]
#         if self.first_last_token_del[0]:
#             start_pos[0] = end_pos[0]
#             start_neighbour[0] = end_neighbour[0]
#         if self.first_last_token_del[1]:
#             end_pos[-1] = start_pos[-1]
#             start_neighbour[-1] = end_neighbour[-1]
        self.deleted_object = pd.DataFrame(np.c_[ start_pos, end_pos, start_neighbour, end_neighbour ],
                                       columns=[ "del_start_pos", "del_end_pos", "left_neigh", "right_neigh",])
    
    def inserted_continuous_pos(self):
        self.content["added"] =  pd.Series(np.isin( self.content["token_id"].values, list(self.added), assume_unique= True))
        end_pos = np.argwhere(np.ediff1d(np.pad(self.content["added"].astype(np.int), (1,1), mode="constant", constant_values=0)) == -1) -1 
        start_pos = np.argwhere(np.ediff1d(np.pad(self.content["added"].astype(np.int), (1,1), mode="constant", constant_values=0)) == 1)
        self.added_pos = np.c_[start_pos, end_pos]

    def inserted_neighbours(self):
        start_token_pos = self.added_pos[:,0] - 1
        end_token_pos = self.added_pos[:,1] + 1
#         self.first_last_token = self.content["added"].values[[0,-1]]
#         if self.first_last_token[0]:
#             start_token_pos[0] = end_token_pos[0]
#         if self.first_last_token[1]:
#             end_token_pos[-1] = start_token_pos[-1]
        self.start_token_id = self.content["token_id"].values[start_token_pos]
        self.end_token_id = self.content["token_id"].values[end_token_pos]
    
    def create_change_object(self, to_rev):
        self.ins_left = np.argwhere(np.isin(self.content.token_id.values, to_rev.start_token_id, assume_unique= True))
        self.ins_right = np.argwhere(np.isin(self.content.token_id.values, to_rev.end_token_id, assume_unique= True))
        self.inserted_object = pd.DataFrame(np.concatenate([to_rev.added_pos, self.ins_left, self.ins_right], axis=1),
                                       columns=["ins_start_pos", "ins_end_pos", "left_neigh", "right_neigh", ])

        self.change = pd.merge(self.inserted_object, self.deleted_object,how="outer", on=["left_neigh", "right_neigh"])
        self.change.fillna(0, inplace=True)
        
#     def find_tokens(self, epsilon_size):
#         self.vocabs_pos = np.argwhere( self.content["invocab"].values)
#         self.content_str_vec = self.content.str.values
#         del self.content


#         return pd.Series([tuple(ins_tokens), tuple(del_tokens), tuple(left_neigh), tuple(right_neigh), tuple(left_token), tuple(right_token)])
    
#     def find_neighbour_tokens(self, change_neigh, epsilon_size):
#         left_neigh_start = change_neigh[0]
#         right_neigh_start = change_neigh[1]
#         left_neigh = self.vocabs_pos[self.vocabs_pos <= left_neigh_start][-epsilon_size:]
#         right_neigh = self.vocabs_pos[self.vocabs_pos >= right_neigh_start][:epsilon_size]
#         left_tokens = tuple(self.content_str_vec[left_neigh])
#         right_tokens = tuple(self.content_str_vec[right_neigh])
#         return np.c_[left_tokens, right_tokens]
        
#     def find_changed_tokens(self, change_pos, epsilon_size):
#         ins_start_pos = change_pos[0]
#         ins_end_pos = change_pos[1]
#         del_start_pos = change_pos[0]
#         del_end_pos = change_pos[1]
#         ins_slice = slice(int(ins_start_pos), int(ins_end_pos)+1 )
#         del_slice = slice(int(del_start_pos), int(del_end_pos)+1 )
#         ins_tokens = tuple(self.content_str_vec[ins_slice])
#         del_tokens = tuple(self.content_str_vec[del_slice])
#         return np.c_[[ins_tokens], [del_tokens]]
    
#     def find_tokens(change, revision, epsilon_size):
#         left_neigh = revision.vocabs_pos[revision.vocabs_pos <= change["left_neigh"]][-epsilon_size:]
#         right_neigh = revision.vocabs_pos[revision.vocabs_pos >= change["right_neigh"]][:epsilon_size]
#         ins_slice = slice(int(change["ins_start_pos"]), int(change["ins_end_pos"]+1) )
#         del_slice = slice(int(change["del_start_pos"]), int(change["del_end_pos"]+1) )
#         left_token = revision.content_str_vec[left_neigh]
#         right_token = revision.content_str_vec[right_neigh]
#         ins_tokens = revision.content_str_vec[ins_slice]
#         del_tokens = revision.content_str_vec[del_slice]
#         return pd.Series([tuple(ins_tokens), tuple(del_tokens), tuple(left_neigh), tuple(right_neigh), tuple(left_token), tuple(right_token)])
        
    def append_neighbour_vec(self, epsilon_size):
        self.vocabs_pos = np.argwhere( self.content["invocab"].values)
        self.content_str_vec = self.content.str.values
#         del self.content
        neighbour_df = self.change.apply(find_tokens, axis=1, args=(self, epsilon_size))
        neighbour_df.columns= ["ins_tokens", "del_tokens", "left_neigh", "right_neigh", "left_token", "right_token"]
        self.neighbour = neighbour_df
        self.change_df = pd.concat([self.change, neighbour_df], sort=False, axis=1)
        
class Change:
    def __init__(self, token, start, end, left_context, right_context):
        self.token = token
        self.start = start
        self.end = end
        self.left = left_context
        self.right = right_context
        
def find_tokens(change, revision, epsilon_size):
    left_neigh = revision.vocabs_pos[revision.vocabs_pos <= change["left_neigh"]][-epsilon_size:]
    right_neigh = revision.vocabs_pos[revision.vocabs_pos >= change["right_neigh"]][:epsilon_size]
    ins_slice = slice(int(change["ins_start_pos"]), int(change["ins_end_pos"]+1) )
    del_slice = slice(int(change["del_start_pos"]), int(change["del_end_pos"]+1) )
    left_token = revision.content_str_vec[left_neigh]
    right_token = revision.content_str_vec[right_neigh]
    ins_tokens = revision.content_str_vec[ins_slice]
    del_tokens = revision.content_str_vec[del_slice]
    return pd.Series([tuple(ins_tokens), tuple(del_tokens), tuple(left_neigh), tuple(right_neigh), tuple(left_token), tuple(right_token)])

# %%
baseurl = "https://api.wikiwho.net/en/api/v1.0.0-beta/"
content = "Violence_against_Muslims_in_India"
revisions_url = os.path.join( baseurl, "rev_ids", content+"/")
params = {"editor": "true", "timestamp": "true"}
response = requests.get(revisions_url, params= params)
revisons_list = response.json()["revisions"]

# %%
all_content_url = os.path.join(baseurl, "all_content", content +"/")
params = { "o_rev_id": "true", "editor": "false", "token_id": "true", "in": "true", "out": "true" }
all_rev_data = requests.get(all_content_url, params= params)
all_tokens_mama = all_rev_data.json()["all_tokens"]

# %%
# %%time
test_wiki = Wiki(2345, "a test wiki", all_tokens=4)
test_wiki.init_revisions(revisons_list)
test_wiki.add_all_token(all_tokens_mama) 
epsilon_size = 6
# del all_tokens_mama
# Out:
# CPU times: user 7.49 s, sys: 16 ms, total: 7.5 s
# Wall time: 7.5 s

# %%
def get_contents(baseurl, content, start_rev_id, end_rev_id=""):
    content_url = os.path.join(baseurl, "rev_content", content, str(start_rev_id)+"/")
    if end_rev_id:
        content_url = os.path.join(content_url, str(end_rev_id)+"/")
    params = { "o_rev_id": "false", "editor": "false", "token_id": "true", "in": "false", "out": "false" }
    rev_contents = requests.get(content_url, params= params).json()["revisions"]
    return rev_contents

# %%
# %%time
# epsilon_size = 6
# test_wiki.revisions.iloc[0].content = pd.DataFrame(list(rev_contents[0].values())[0]["tokens"])
# from_index = 0
# for rev_content in rev_contents[1:]:
#     from_rev = test_wiki.revisions.iloc[from_index]
#     to_rev = test_wiki.revisions.iloc[from_index+1]
#     from_index += 1
#     from_rev.deleted(to_rev)
#     from_rev.content["invocab"] = from_rev.content["str"].isin(vocab)
#     to_rev.content = pd.DataFrame(list(rev_content.values())[0]["tokens"])
#     to_rev.inserted_continuous_pos()
#     to_rev.inserted_neighbours()
#     from_rev.create_change_object(to_rev)
#     from_rev.append_neighbour_vec(epsilon_size)

# %%
def create_change(wiki, rev_contents, from_index, vocab, epsilon_size):
    for rev_content in rev_contents:
        try:
            f_rev = wiki.revisions.iloc[from_index]
            t_rev = wiki.revisions.iloc[from_index+1]
            from_index += 1
            f_rev.deleted(t_rev)
            f_rev.content["invocab"] = f_rev.content["str"].isin(vocab)
            tokens = list(rev_content.values())[0]["tokens"]
            tokens.insert(0, {'token_id':-1, 'str':  "{st@rt}"})
            tokens.append({'token_id':-2, 'str': "{$nd}"})
            t_rev.content = pd.DataFrame(tokens)
            t_rev.inserted_continuous_pos()
            t_rev.inserted_neighbours()
            f_rev.create_change_object(t_rev)
            f_rev.append_neighbour_vec(epsilon_size)
        except:
            print("problem in ", rev_content.keys() )
    return from_index

# %%
# %%time
# rev_contents = get_contents(baseurl, content, str(revisons_list[0]["id"]), str(revisons_list[1]["id"]))

# epsilon_size = 6
# test_wiki.revisions.iloc[0].content = pd.DataFrame(list(rev_contents[0].values())[0]["tokens"])
# from_index = 0

# %%
# %%time
rev_contents = get_contents(baseurl, content, str(revisons_list[0]["id"]), str(revisons_list[1]["id"]))
epsilon_size = 6
tokens = list(rev_contents[0].values())[0]["tokens"]
tokens.insert(0, {'token_id':-1, 'str':  "{st@rt}"})
tokens.append({'token_id':-2, 'str': "{$nd}"})
test_wiki.revisions.iloc[0].content = pd.DataFrame(tokens)
from_index = 0
if len(revisons_list) > 200:
    step = 200
else:
    step = len(revisons_list)
start_index = from_index + 1
end_index = len(revisons_list)
for to_index in  range(start_index, end_index, step):
    try:
        rev_contents = get_contents(baseurl, content, str(revisons_list[(from_index+1)]["id"]), str(revisons_list[to_index]["id"]))
        create_change(test_wiki, rev_contents, from_index, vocab, epsilon_size)
        print("ran till", to_index)
        from_index = to_index - 1
    except:
        print("problem ", from_index)
to_index = from_index + (end_index-1)%step
rev_contents = get_contents(baseurl, content, str(revisons_list[(from_index+1)]["id"]), str(revisons_list[to_index]["id"]))
create_change(test_wiki, rev_contents, from_index, vocab, epsilon_size)
from_index = to_index - 1
rev_contents = get_contents(baseurl, content, str(revisons_list[(from_index+1)]["id"]), "")
create_change(test_wiki, rev_contents, from_index, vocab, epsilon_size)
# Out:
# ran till 1
# problem in  dict_keys(['558137760'])
# problem in  dict_keys(['558138007'])
# problem in  dict_keys(['558138375'])
# problem in  dict_keys(['558140223'])
# problem in  dict_keys(['558140376'])
# problem in  dict_keys(['558140784'])
# problem in  dict_keys(['558155934'])
# problem in  dict_keys(['558238335'])
# problem in  dict_keys(['558244871'])
# problem in  dict_keys(['558249320'])
# problem in  dict_keys(['558256275'])
# problem in  dict_keys(['558256307'])
# problem in  dict_keys(['558397658'])
# problem in  dict_keys(['558531547'])
# problem in  dict_keys(['558603673'])
# problem in  dict_keys(['558605394'])
# problem in  dict_keys(['558605478'])
# problem in  dict_keys(['558605732'])
# problem in  dict_keys(['558605803'])
# problem in  dict_keys(['558608390'])
# problem in  dict_keys(['558610600'])
# problem in  dict_keys(['558610905'])
# problem in  dict_keys(['558613621'])
# problem in  dict_keys(['558639241'])
# problem in  dict_keys(['558640600'])
# problem in  dict_keys(['558640982'])
# problem in  dict_keys(['558646747'])
# problem in  dict_keys(['558649286'])
# problem in  dict_keys(['558705625'])
# problem in  dict_keys(['558707221'])
# problem in  dict_keys(['558709412'])
# problem in  dict_keys(['558709567'])
# problem in  dict_keys(['558709661'])
# problem in  dict_keys(['558711162'])
# problem in  dict_keys(['558714896'])
# problem in  dict_keys(['558715743'])
# problem in  dict_keys(['558718250'])
# problem in  dict_keys(['558724031'])
# problem in  dict_keys(['558724796'])
# problem in  dict_keys(['558725621'])
# problem in  dict_keys(['558726684'])
# problem in  dict_keys(['558739880'])
# problem in  dict_keys(['558739929'])
# problem in  dict_keys(['558751686'])
# problem in  dict_keys(['558813166'])
# problem in  dict_keys(['558830705'])
# problem in  dict_keys(['558927331'])
# problem in  dict_keys(['559018933'])
# problem in  dict_keys(['559019396'])
# problem in  dict_keys(['559020783'])
# problem in  dict_keys(['559021507'])
# problem in  dict_keys(['559022316'])
# problem in  dict_keys(['559048172'])
# problem in  dict_keys(['559049951'])
# problem in  dict_keys(['559540497'])
# problem in  dict_keys(['561325772'])
# problem in  dict_keys(['561328305'])
# problem in  dict_keys(['561341241'])
# problem in  dict_keys(['561359828'])
# problem in  dict_keys(['561366470'])
# problem in  dict_keys(['561368150'])
# problem in  dict_keys(['561368412'])
# problem in  dict_keys(['561377816'])
# problem in  dict_keys(['561380143'])
# problem in  dict_keys(['561382765'])
# problem in  dict_keys(['561382916'])
# problem in  dict_keys(['561383377'])
# problem in  dict_keys(['561383448'])
# problem in  dict_keys(['561383493'])
# problem in  dict_keys(['561383561'])
# problem in  dict_keys(['561383665'])
# problem in  dict_keys(['561413917'])
# problem in  dict_keys(['561415360'])
# problem in  dict_keys(['561419515'])
# problem in  dict_keys(['561428317'])
# problem in  dict_keys(['561428553'])
# problem in  dict_keys(['561430600'])
# problem in  dict_keys(['561434615'])
# problem in  dict_keys(['561434839'])
# problem in  dict_keys(['561436907'])
# problem in  dict_keys(['561494324'])
# problem in  dict_keys(['561499713'])
# problem in  dict_keys(['561501383'])
# problem in  dict_keys(['561501806'])
# problem in  dict_keys(['561503430'])
# problem in  dict_keys(['561503678'])
# problem in  dict_keys(['561504122'])
# problem in  dict_keys(['561504479'])
# problem in  dict_keys(['561504878'])
# problem in  dict_keys(['561507316'])
# problem in  dict_keys(['561507427'])
# problem in  dict_keys(['561528780'])
# problem in  dict_keys(['561529497'])
# problem in  dict_keys(['561534916'])
# problem in  dict_keys(['561579704'])
# problem in  dict_keys(['561816236'])
# problem in  dict_keys(['561852654'])
# problem in  dict_keys(['561853635'])
# problem in  dict_keys(['561857147'])
# problem in  dict_keys(['561862110'])
# problem in  dict_keys(['561866843'])
# problem in  dict_keys(['561879399'])
# problem in  dict_keys(['561887480'])
# problem in  dict_keys(['561888709'])
# problem in  dict_keys(['561888776'])
# problem in  dict_keys(['561889155'])
# problem in  dict_keys(['561889539'])
# problem in  dict_keys(['561889586'])
# problem in  dict_keys(['561890553'])
# problem in  dict_keys(['561890618'])
# problem in  dict_keys(['561891600'])
# problem in  dict_keys(['561891654'])
# problem in  dict_keys(['561891687'])
# problem in  dict_keys(['561892185'])
# problem in  dict_keys(['561892314'])
# problem in  dict_keys(['561893175'])
# problem in  dict_keys(['561893395'])
# problem in  dict_keys(['561894462'])
# problem in  dict_keys(['561894729'])
# problem in  dict_keys(['561894859'])
# problem in  dict_keys(['561894916'])
# problem in  dict_keys(['561894967'])
# problem in  dict_keys(['561951459'])
# problem in  dict_keys(['562017549'])
# problem in  dict_keys(['562017637'])
# problem in  dict_keys(['562037151'])
# problem in  dict_keys(['562037272'])
# problem in  dict_keys(['562039384'])
# problem in  dict_keys(['562040784'])
# problem in  dict_keys(['562044801'])
# problem in  dict_keys(['562092781'])
# problem in  dict_keys(['562093741'])
# problem in  dict_keys(['562094539'])
# problem in  dict_keys(['562110673'])
# problem in  dict_keys(['562111220'])
# problem in  dict_keys(['562124776'])
# problem in  dict_keys(['562139552'])
# problem in  dict_keys(['562262831'])
# problem in  dict_keys(['562298387'])
# problem in  dict_keys(['562464199'])
# problem in  dict_keys(['562524988'])
# problem in  dict_keys(['563322172'])
# problem in  dict_keys(['563491575'])
# problem in  dict_keys(['563493972'])
# problem in  dict_keys(['563513165'])
# problem in  dict_keys(['563520760'])
# problem in  dict_keys(['563521015'])
# problem in  dict_keys(['563522449'])
# problem in  dict_keys(['563522596'])
# problem in  dict_keys(['563523360'])
# problem in  dict_keys(['563524027'])
# problem in  dict_keys(['563524332'])
# problem in  dict_keys(['563529113'])
# problem in  dict_keys(['563529284'])
# problem in  dict_keys(['563529586'])
# problem in  dict_keys(['563529792'])
# problem in  dict_keys(['563530804'])
# problem in  dict_keys(['563530865'])
# problem in  dict_keys(['563533345'])
# problem in  dict_keys(['563546072'])
# problem in  dict_keys(['563546391'])
# problem in  dict_keys(['563546864'])
# problem in  dict_keys(['563547339'])
# problem in  dict_keys(['563547548'])
# problem in  dict_keys(['563547587'])
# problem in  dict_keys(['563548406'])
# problem in  dict_keys(['563794244'])
# problem in  dict_keys(['563794869'])
# problem in  dict_keys(['563797036'])
# problem in  dict_keys(['563797153'])
# problem in  dict_keys(['563799460'])
# problem in  dict_keys(['563823685'])
# problem in  dict_keys(['563834706'])
# problem in  dict_keys(['563835395'])
# problem in  dict_keys(['563842921'])
# problem in  dict_keys(['563846305'])
# problem in  dict_keys(['563846985'])
# problem in  dict_keys(['563951788'])
# problem in  dict_keys(['564547878'])
# problem in  dict_keys(['564550442'])
# problem in  dict_keys(['564551184'])
# problem in  dict_keys(['564552469'])
# problem in  dict_keys(['564578564'])
# problem in  dict_keys(['564578841'])
# problem in  dict_keys(['564634871'])
# problem in  dict_keys(['564635063'])
# problem in  dict_keys(['564643636'])
# problem in  dict_keys(['564652764'])
# problem in  dict_keys(['564662373'])
# problem in  dict_keys(['564730926'])
# problem in  dict_keys(['564731103'])
# problem in  dict_keys(['564732182'])
# problem in  dict_keys(['564733798'])
# problem in  dict_keys(['564735528'])
# problem in  dict_keys(['564757141'])
# problem in  dict_keys(['564775414'])
# problem in  dict_keys(['564783775'])
# problem in  dict_keys(['564784625'])
# problem in  dict_keys(['564892938'])
# problem in  dict_keys(['564894873'])
# ran till 201
# problem in  dict_keys(['565016275'])
# problem in  dict_keys(['565059522'])
# problem in  dict_keys(['565790624'])
# problem in  dict_keys(['565791167'])
# problem in  dict_keys(['566196847'])
# problem in  dict_keys(['566197025'])
# problem in  dict_keys(['566604160'])
# problem in  dict_keys(['566745555'])
# problem in  dict_keys(['566751669'])
# problem in  dict_keys(['566973685'])
# problem in  dict_keys(['568252678'])
# problem in  dict_keys(['568326070'])
# problem in  dict_keys(['568359611'])
# problem in  dict_keys(['568359715'])
# problem in  dict_keys(['568890261'])
# problem in  dict_keys(['568944113'])
# problem in  dict_keys(['568986590'])
# problem in  dict_keys(['568987421'])
# problem in  dict_keys(['568987983'])
# problem in  dict_keys(['568988150'])
# problem in  dict_keys(['568989202'])
# problem in  dict_keys(['568990123'])
# problem in  dict_keys(['568993284'])
# problem in  dict_keys(['568994904'])
# problem in  dict_keys(['568996520'])
# problem in  dict_keys(['568997107'])
# problem in  dict_keys(['568997855'])
# problem in  dict_keys(['568999007'])
# problem in  dict_keys(['568999370'])
# problem in  dict_keys(['569006911'])
# problem in  dict_keys(['569007061'])
# problem in  dict_keys(['569007313'])
# problem in  dict_keys(['569007909'])
# problem in  dict_keys(['569008026'])
# problem in  dict_keys(['569008291'])
# problem in  dict_keys(['569008467'])
# problem in  dict_keys(['569051568'])
# problem in  dict_keys(['571012359'])
# problem in  dict_keys(['571012550'])
# problem in  dict_keys(['571012682'])
# problem in  dict_keys(['571043940'])
# problem in  dict_keys(['571060444'])
# problem in  dict_keys(['571520623'])
# problem in  dict_keys(['571520904'])
# problem in  dict_keys(['571526846'])
# problem in  dict_keys(['571529804'])
# problem in  dict_keys(['572789444'])
# problem in  dict_keys(['572790339'])
# problem in  dict_keys(['572792331'])
# problem in  dict_keys(['572793135'])
# problem in  dict_keys(['575477268'])
# problem in  dict_keys(['575555229'])
# problem in  dict_keys(['575752853'])
# problem in  dict_keys(['575755300'])
# problem in  dict_keys(['575756430'])
# problem in  dict_keys(['575789984'])
# problem in  dict_keys(['575791545'])
# problem in  dict_keys(['575793654'])
# problem in  dict_keys(['579891840'])
# problem in  dict_keys(['579993923'])
# problem in  dict_keys(['581289001'])
# problem in  dict_keys(['581291894'])
# problem in  dict_keys(['581292155'])
# problem in  dict_keys(['581293394'])
# problem in  dict_keys(['581295192'])
# problem in  dict_keys(['581295465'])
# problem in  dict_keys(['581300210'])
# problem in  dict_keys(['581312753'])
# problem in  dict_keys(['582083225'])
# problem in  dict_keys(['583806338'])
# problem in  dict_keys(['583810976'])
# problem in  dict_keys(['584508070'])
# problem in  dict_keys(['584574351'])
# problem in  dict_keys(['584943519'])
# problem in  dict_keys(['584943836'])
# problem in  dict_keys(['585127376'])
# problem in  dict_keys(['585127491'])
# problem in  dict_keys(['585127573'])
# problem in  dict_keys(['585127823'])
# problem in  dict_keys(['585396987'])
# problem in  dict_keys(['585397267'])
# problem in  dict_keys(['585397358'])
# problem in  dict_keys(['585397445'])
# problem in  dict_keys(['585544867'])
# problem in  dict_keys(['585582943'])
# problem in  dict_keys(['586348385'])
# problem in  dict_keys(['586348652'])
# problem in  dict_keys(['586348848'])
# problem in  dict_keys(['586356054'])
# problem in  dict_keys(['586730098'])
# problem in  dict_keys(['586939714'])
# problem in  dict_keys(['586940067'])
# problem in  dict_keys(['586940227'])
# problem in  dict_keys(['586942519'])
# problem in  dict_keys(['586950536'])
# problem in  dict_keys(['586951528'])
# problem in  dict_keys(['587007939'])
# problem in  dict_keys(['587009714'])
# problem in  dict_keys(['587040388'])
# problem in  dict_keys(['587195237'])
# problem in  dict_keys(['587811154'])
# problem in  dict_keys(['587811712'])
# problem in  dict_keys(['587812114'])
# problem in  dict_keys(['587813991'])
# problem in  dict_keys(['587814501'])
# problem in  dict_keys(['587815659'])
# problem in  dict_keys(['587817621'])
# problem in  dict_keys(['587886320'])
# problem in  dict_keys(['587888456'])
# problem in  dict_keys(['589095240'])
# problem in  dict_keys(['590595353'])
# problem in  dict_keys(['592497503'])
# problem in  dict_keys(['592498033'])
# problem in  dict_keys(['592597332'])
# problem in  dict_keys(['592625067'])
# problem in  dict_keys(['593725005'])
# problem in  dict_keys(['598575094'])
# problem in  dict_keys(['598575584'])
# problem in  dict_keys(['599005012'])
# problem in  dict_keys(['599005414'])
# problem in  dict_keys(['599151477'])
# problem in  dict_keys(['599161780'])
# problem in  dict_keys(['599181677'])
# problem in  dict_keys(['599182069'])
# problem in  dict_keys(['599311005'])
# problem in  dict_keys(['599311423'])
# problem in  dict_keys(['599333672'])
# problem in  dict_keys(['599453236'])
# problem in  dict_keys(['599453702'])
# problem in  dict_keys(['599729459'])
# problem in  dict_keys(['599729692'])
# problem in  dict_keys(['600175195'])
# problem in  dict_keys(['600176500'])
# problem in  dict_keys(['600205070'])
# problem in  dict_keys(['600207990'])
# problem in  dict_keys(['600802962'])
# problem in  dict_keys(['600804528'])
# problem in  dict_keys(['601005829'])
# problem in  dict_keys(['601006189'])
# problem in  dict_keys(['601043850'])
# problem in  dict_keys(['602770060'])
# problem in  dict_keys(['602777523'])
# problem in  dict_keys(['603350796'])
# problem in  dict_keys(['603351623'])
# problem in  dict_keys(['603366261'])
# problem in  dict_keys(['603366419'])
# problem in  dict_keys(['603478013'])
# problem in  dict_keys(['603478829'])
# problem in  dict_keys(['603480983'])
# problem in  dict_keys(['603486183'])
# problem in  dict_keys(['603486685'])
# problem in  dict_keys(['603486787'])
# problem in  dict_keys(['603489139'])
# problem in  dict_keys(['603489270'])
# problem in  dict_keys(['603489500'])
# problem in  dict_keys(['603489608'])
# problem in  dict_keys(['604146321'])
# problem in  dict_keys(['608667294'])
# problem in  dict_keys(['608667433'])
# problem in  dict_keys(['609201483'])
# problem in  dict_keys(['609204406'])
# problem in  dict_keys(['609205199'])
# problem in  dict_keys(['609215056'])
# problem in  dict_keys(['609658917'])
# problem in  dict_keys(['609759941'])
# problem in  dict_keys(['610167239'])
# problem in  dict_keys(['610167300'])
# problem in  dict_keys(['610167382'])
# problem in  dict_keys(['611195430'])
# problem in  dict_keys(['611196824'])
# problem in  dict_keys(['611971959'])
# problem in  dict_keys(['612384652'])
# problem in  dict_keys(['612394573'])
# problem in  dict_keys(['612394905'])
# problem in  dict_keys(['612409803'])
# problem in  dict_keys(['612513740'])
# problem in  dict_keys(['612513811'])
# problem in  dict_keys(['612514820'])
# problem in  dict_keys(['612516631'])
# problem in  dict_keys(['612578804'])
# problem in  dict_keys(['612783670'])
# problem in  dict_keys(['612783760'])
# problem in  dict_keys(['612784099'])
# problem in  dict_keys(['612784892'])
# problem in  dict_keys(['612788046'])
# problem in  dict_keys(['612788531'])
# problem in  dict_keys(['612789633'])
# problem in  dict_keys(['612790526'])
# problem in  dict_keys(['612790843'])
# problem in  dict_keys(['612791435'])
# problem in  dict_keys(['612791766'])
# problem in  dict_keys(['612792374'])
# problem in  dict_keys(['612811622'])
# problem in  dict_keys(['612819470'])
# problem in  dict_keys(['613192697'])
# problem in  dict_keys(['613282245'])
# problem in  dict_keys(['614901615'])
# problem in  dict_keys(['614902132'])
# problem in  dict_keys(['614905632'])
# problem in  dict_keys(['615847948'])
# ran till 401
# problem in  dict_keys(['617200833'])
# problem in  dict_keys(['617200891'])
# problem in  dict_keys(['617201281'])
# problem in  dict_keys(['617201449'])
# problem in  dict_keys(['619661399'])
# problem in  dict_keys(['620392571'])
# problem in  dict_keys(['620399592'])
# problem in  dict_keys(['620819541'])
# problem in  dict_keys(['623708296'])
# problem in  dict_keys(['624194288'])
# problem in  dict_keys(['624194375'])
# problem in  dict_keys(['624197675'])
# problem in  dict_keys(['626740603'])
# problem in  dict_keys(['626740779'])
# problem in  dict_keys(['626747021'])
# problem in  dict_keys(['630772225'])
# problem in  dict_keys(['630772509'])
# problem in  dict_keys(['630775661'])
# problem in  dict_keys(['630839978'])
# problem in  dict_keys(['630840971'])
# problem in  dict_keys(['631065593'])
# problem in  dict_keys(['631073806'])
# problem in  dict_keys(['631153194'])
# problem in  dict_keys(['631182466'])
# problem in  dict_keys(['631814143'])
# problem in  dict_keys(['631858113'])
# problem in  dict_keys(['633502253'])
# problem in  dict_keys(['633502837'])
# problem in  dict_keys(['633573313'])
# problem in  dict_keys(['634994950'])
# problem in  dict_keys(['634995653'])
# problem in  dict_keys(['634995804'])
# problem in  dict_keys(['634996265'])
# problem in  dict_keys(['635007983'])
# problem in  dict_keys(['638737001'])
# problem in  dict_keys(['638808214'])
# problem in  dict_keys(['639399772'])
# problem in  dict_keys(['640489628'])
# problem in  dict_keys(['640489688'])
# problem in  dict_keys(['640525372'])
# problem in  dict_keys(['640529354'])
# problem in  dict_keys(['640542155'])
# problem in  dict_keys(['641433388'])
# problem in  dict_keys(['641454480'])
# problem in  dict_keys(['643175907'])
# problem in  dict_keys(['643176088'])
# problem in  dict_keys(['643176189'])
# problem in  dict_keys(['643176741'])
# problem in  dict_keys(['643176771'])
# problem in  dict_keys(['643177030'])
# problem in  dict_keys(['643177275'])
# problem in  dict_keys(['643188895'])
# problem in  dict_keys(['645284557'])
# problem in  dict_keys(['645284628'])
# problem in  dict_keys(['645307503'])
# problem in  dict_keys(['647782159'])
# problem in  dict_keys(['648900565'])
# problem in  dict_keys(['648905547'])
# problem in  dict_keys(['650427640'])
# problem in  dict_keys(['650431541'])
# problem in  dict_keys(['651613511'])
# problem in  dict_keys(['651613696'])
# problem in  dict_keys(['651613728'])
# problem in  dict_keys(['652895437'])
# problem in  dict_keys(['653096544'])
# problem in  dict_keys(['653588804'])
# problem in  dict_keys(['654448855'])
# problem in  dict_keys(['654510966'])
# problem in  dict_keys(['654512928'])
# problem in  dict_keys(['654621058'])
# problem in  dict_keys(['654634515'])
# problem in  dict_keys(['654760262'])
# problem in  dict_keys(['654768005'])
# problem in  dict_keys(['654768828'])
# problem in  dict_keys(['654768985'])
# problem in  dict_keys(['654769163'])
# problem in  dict_keys(['654769626'])
# problem in  dict_keys(['655239430'])
# problem in  dict_keys(['655251026'])
# problem in  dict_keys(['655251129'])
# problem in  dict_keys(['655459695'])
# problem in  dict_keys(['655513103'])
# problem in  dict_keys(['655528726'])
# problem in  dict_keys(['655618456'])
# problem in  dict_keys(['657197142'])
# problem in  dict_keys(['657201159'])
# problem in  dict_keys(['657276908'])
# problem in  dict_keys(['657276974'])
# problem in  dict_keys(['657278646'])
# problem in  dict_keys(['660016213'])
# problem in  dict_keys(['665833240'])
# problem in  dict_keys(['665833284'])
# problem in  dict_keys(['665854002'])
# problem in  dict_keys(['669874825'])
# problem in  dict_keys(['669954465'])
# problem in  dict_keys(['669955276'])
# problem in  dict_keys(['669957060'])
# problem in  dict_keys(['670012122'])
# problem in  dict_keys(['670054435'])
# problem in  dict_keys(['670324610'])
# problem in  dict_keys(['672404078'])
# problem in  dict_keys(['672425627'])
# problem in  dict_keys(['674115121'])
# problem in  dict_keys(['674116674'])
# problem in  dict_keys(['674116964'])
# problem in  dict_keys(['674118999'])
# problem in  dict_keys(['674262304'])
# problem in  dict_keys(['674264081'])
# problem in  dict_keys(['674803284'])
# problem in  dict_keys(['674929831'])
# problem in  dict_keys(['674930437'])
# problem in  dict_keys(['674931006'])
# problem in  dict_keys(['674931569'])
# problem in  dict_keys(['674932524'])
# problem in  dict_keys(['674932849'])
# problem in  dict_keys(['674933740'])
# problem in  dict_keys(['674933998'])
# problem in  dict_keys(['674934870'])
# problem in  dict_keys(['674934953'])
# problem in  dict_keys(['674935928'])
# problem in  dict_keys(['674936922'])
# problem in  dict_keys(['674937150'])
# problem in  dict_keys(['674938982'])
# problem in  dict_keys(['674940578'])
# problem in  dict_keys(['674940991'])
# problem in  dict_keys(['674941072'])
# problem in  dict_keys(['674941188'])
# problem in  dict_keys(['674941264'])
# problem in  dict_keys(['674941411'])
# problem in  dict_keys(['674941857'])
# problem in  dict_keys(['674942497'])
# problem in  dict_keys(['674942561'])
# problem in  dict_keys(['675027065'])
# problem in  dict_keys(['675028334'])
# problem in  dict_keys(['675094673'])
# problem in  dict_keys(['675094985'])
# problem in  dict_keys(['675101761'])
# problem in  dict_keys(['675101897'])
# problem in  dict_keys(['675102250'])
# problem in  dict_keys(['675102401'])
# problem in  dict_keys(['675127309'])
# problem in  dict_keys(['677392683'])
# problem in  dict_keys(['677393292'])
# problem in  dict_keys(['677393778'])
# problem in  dict_keys(['677394506'])
# problem in  dict_keys(['677394705'])
# problem in  dict_keys(['677394758'])
# problem in  dict_keys(['677395187'])
# problem in  dict_keys(['677395300'])
# problem in  dict_keys(['677396854'])
# problem in  dict_keys(['677396932'])
# problem in  dict_keys(['677432980'])
# problem in  dict_keys(['678572613'])
# problem in  dict_keys(['678584555'])
# problem in  dict_keys(['678830389'])
# problem in  dict_keys(['678899455'])
# problem in  dict_keys(['678901217'])
# problem in  dict_keys(['678901783'])
# problem in  dict_keys(['678918951'])
# problem in  dict_keys(['683497342'])
# problem in  dict_keys(['683504918'])
# problem in  dict_keys(['684393984'])
# problem in  dict_keys(['684394709'])
# problem in  dict_keys(['684395742'])
# problem in  dict_keys(['685042041'])
# problem in  dict_keys(['685044585'])
# problem in  dict_keys(['685828256'])
# problem in  dict_keys(['685828376'])
# problem in  dict_keys(['685828876'])
# problem in  dict_keys(['687629462'])
# problem in  dict_keys(['689628462'])
# problem in  dict_keys(['689628482'])
# problem in  dict_keys(['690401834'])
# problem in  dict_keys(['690402085'])
# problem in  dict_keys(['690569138'])
# problem in  dict_keys(['690794995'])
# problem in  dict_keys(['691389827'])
# problem in  dict_keys(['692394826'])
# problem in  dict_keys(['692582488'])
# problem in  dict_keys(['696963116'])
# problem in  dict_keys(['696963682'])
# problem in  dict_keys(['697089262'])
# problem in  dict_keys(['701899580'])
# problem in  dict_keys(['701913925'])
# problem in  dict_keys(['704513649'])
# problem in  dict_keys(['704513697'])
# problem in  dict_keys(['704518855'])
# problem in  dict_keys(['704520432'])
# problem in  dict_keys(['705399286'])
# problem in  dict_keys(['708615888'])
# problem in  dict_keys(['708616109'])
# problem in  dict_keys(['708616632'])
# problem in  dict_keys(['708616778'])
# problem in  dict_keys(['710027812'])
# problem in  dict_keys(['710028264'])
# problem in  dict_keys(['710029232'])
# problem in  dict_keys(['710032884'])
# problem in  dict_keys(['710033338'])
# problem in  dict_keys(['710036715'])
# problem in  dict_keys(['710038354'])
# ran till 601
# problem in  dict_keys(['710039294'])
# problem in  dict_keys(['710040017'])
# problem in  dict_keys(['710040267'])
# problem in  dict_keys(['710043085'])
# problem in  dict_keys(['710049288'])
# problem in  dict_keys(['710049621'])
# problem in  dict_keys(['710050711'])
# problem in  dict_keys(['710051970'])
# problem in  dict_keys(['710056388'])
# problem in  dict_keys(['710056993'])
# problem in  dict_keys(['710060049'])
# problem in  dict_keys(['710069355'])
# problem in  dict_keys(['710621868'])
# problem in  dict_keys(['711837127'])
# problem in  dict_keys(['711839340'])
# problem in  dict_keys(['712540285'])
# problem in  dict_keys(['712540960'])
# problem in  dict_keys(['712610287'])
# problem in  dict_keys(['712614406'])
# problem in  dict_keys(['714359215'])
# problem in  dict_keys(['714376074'])
# problem in  dict_keys(['714377945'])
# problem in  dict_keys(['714475148'])
# problem in  dict_keys(['714475863'])
# problem in  dict_keys(['716056199'])
# problem in  dict_keys(['717227416'])
# problem in  dict_keys(['717227556'])
# problem in  dict_keys(['717227740'])
# problem in  dict_keys(['717227889'])
# problem in  dict_keys(['717235223'])
# problem in  dict_keys(['717235332'])
# problem in  dict_keys(['717235741'])
# problem in  dict_keys(['717236324'])
# problem in  dict_keys(['717236715'])
# problem in  dict_keys(['717237871'])
# problem in  dict_keys(['717238011'])
# problem in  dict_keys(['717238229'])
# problem in  dict_keys(['717240059'])
# problem in  dict_keys(['717240254'])
# problem in  dict_keys(['717240418'])
# problem in  dict_keys(['717240705'])
# problem in  dict_keys(['717240907'])
# problem in  dict_keys(['717241340'])
# problem in  dict_keys(['717242225'])
# problem in  dict_keys(['717242784'])
# problem in  dict_keys(['717242920'])
# problem in  dict_keys(['717247914'])
# problem in  dict_keys(['717248380'])
# problem in  dict_keys(['717249452'])
# problem in  dict_keys(['717264572'])
# problem in  dict_keys(['717290748'])
# problem in  dict_keys(['719545744'])
# problem in  dict_keys(['719545784'])
# problem in  dict_keys(['720853339'])
# problem in  dict_keys(['721698439'])
# problem in  dict_keys(['721698493'])
# problem in  dict_keys(['721698639'])
# problem in  dict_keys(['721698863'])
# problem in  dict_keys(['722458686'])
# problem in  dict_keys(['722458870'])
# problem in  dict_keys(['723667456'])
# problem in  dict_keys(['726520744'])
# problem in  dict_keys(['734714456'])
# problem in  dict_keys(['734714460'])
# problem in  dict_keys(['735524207'])
# problem in  dict_keys(['735524359'])
# problem in  dict_keys(['735526784'])
# problem in  dict_keys(['735916090'])
# problem in  dict_keys(['739168276'])
# problem in  dict_keys(['739168422'])
# problem in  dict_keys(['739168711'])
# problem in  dict_keys(['739169663'])
# problem in  dict_keys(['739713400'])
# problem in  dict_keys(['741426102'])
# problem in  dict_keys(['741426212'])
# problem in  dict_keys(['741447003'])
# problem in  dict_keys(['741652695'])
# problem in  dict_keys(['743966378'])
# problem in  dict_keys(['744092941'])
# problem in  dict_keys(['746457541'])
# problem in  dict_keys(['746457624'])
# problem in  dict_keys(['747812510'])
# problem in  dict_keys(['747816706'])
# problem in  dict_keys(['748190709'])
# problem in  dict_keys(['748813860'])
# problem in  dict_keys(['748816788'])
# problem in  dict_keys(['750039165'])
# problem in  dict_keys(['750039292'])
# problem in  dict_keys(['750039397'])
# problem in  dict_keys(['750039443'])
# problem in  dict_keys(['750039478'])
# problem in  dict_keys(['750039511'])
# problem in  dict_keys(['750039531'])
# problem in  dict_keys(['750039992'])
# problem in  dict_keys(['752969765'])
# problem in  dict_keys(['754580593'])
# problem in  dict_keys(['756945419'])
# problem in  dict_keys(['756945428'])
# problem in  dict_keys(['756945488'])
# problem in  dict_keys(['756945508'])
# problem in  dict_keys(['760289064'])
# problem in  dict_keys(['762027338'])
# problem in  dict_keys(['762027415'])
# problem in  dict_keys(['762027452'])
# problem in  dict_keys(['762027478'])
# problem in  dict_keys(['762027540'])
# problem in  dict_keys(['764157387'])
# problem in  dict_keys(['765226645'])
# problem in  dict_keys(['765238251'])
# problem in  dict_keys(['766402834'])
# problem in  dict_keys(['766407608'])
# problem in  dict_keys(['766482937'])
# problem in  dict_keys(['767266146'])
# problem in  dict_keys(['767266300'])
# problem in  dict_keys(['770210116'])
# problem in  dict_keys(['770233608'])
# problem in  dict_keys(['773960438'])
# problem in  dict_keys(['774132170'])
# problem in  dict_keys(['774132346'])
# problem in  dict_keys(['774136743'])
# problem in  dict_keys(['774264448'])
# problem in  dict_keys(['774264495'])
# problem in  dict_keys(['774264524'])
# problem in  dict_keys(['774269014'])
# problem in  dict_keys(['776479749'])
# problem in  dict_keys(['776479952'])
# problem in  dict_keys(['776481614'])
# problem in  dict_keys(['776482764'])
# problem in  dict_keys(['776689658'])
# problem in  dict_keys(['776690961'])
# problem in  dict_keys(['778104545'])
# problem in  dict_keys(['778107981'])
# problem in  dict_keys(['778111592'])
# problem in  dict_keys(['778678338'])
# problem in  dict_keys(['778679356'])
# problem in  dict_keys(['781677023'])
# problem in  dict_keys(['781680957'])
# problem in  dict_keys(['782165972'])
# problem in  dict_keys(['782169773'])
# problem in  dict_keys(['783460983'])
# problem in  dict_keys(['783461344'])
# problem in  dict_keys(['783461466'])
# problem in  dict_keys(['783462019'])
# problem in  dict_keys(['783462863'])
# problem in  dict_keys(['783465536'])
# problem in  dict_keys(['784489182'])
# problem in  dict_keys(['784489319'])
# problem in  dict_keys(['785729992'])
# problem in  dict_keys(['785730022'])
# problem in  dict_keys(['787214188'])
# problem in  dict_keys(['787216926'])
# problem in  dict_keys(['787217043'])
# problem in  dict_keys(['787217199'])
# problem in  dict_keys(['788338916'])
# problem in  dict_keys(['789573054'])
# problem in  dict_keys(['789573334'])
# problem in  dict_keys(['789636750'])
# problem in  dict_keys(['790446612'])
# problem in  dict_keys(['790759313'])
# problem in  dict_keys(['793130794'])
# problem in  dict_keys(['793178863'])
# problem in  dict_keys(['795620294'])
# problem in  dict_keys(['795620550'])
# problem in  dict_keys(['795620996'])
# problem in  dict_keys(['796539522'])
# problem in  dict_keys(['796545698'])
# problem in  dict_keys(['796634382'])
# problem in  dict_keys(['796731894'])
# problem in  dict_keys(['799991564'])
# problem in  dict_keys(['800018296'])
# problem in  dict_keys(['801250098'])
# problem in  dict_keys(['801741048'])
# problem in  dict_keys(['801958811'])
# problem in  dict_keys(['802596599'])
# problem in  dict_keys(['802596992'])
# problem in  dict_keys(['803441052'])
# problem in  dict_keys(['803628661'])
# problem in  dict_keys(['806622248'])
# problem in  dict_keys(['806622280'])
# problem in  dict_keys(['806622371'])
# problem in  dict_keys(['806622422'])
# problem in  dict_keys(['808087222'])
# problem in  dict_keys(['808087234'])
# problem in  dict_keys(['808087483'])
# problem in  dict_keys(['808087756'])
# problem in  dict_keys(['810220302'])
# problem in  dict_keys(['810403693'])
# problem in  dict_keys(['812875217'])
# problem in  dict_keys(['812875280'])
# problem in  dict_keys(['812875363'])
# problem in  dict_keys(['812875421'])
# problem in  dict_keys(['812878125'])
# problem in  dict_keys(['812878300'])
# problem in  dict_keys(['812892745'])
# problem in  dict_keys(['813836196'])
# problem in  dict_keys(['813836305'])
# problem in  dict_keys(['813836787'])
# problem in  dict_keys(['813837656'])
# problem in  dict_keys(['816103175'])
# problem in  dict_keys(['816103315'])
# ran till 801
# problem in  dict_keys(['817182204'])
# problem in  dict_keys(['817182311'])
# problem in  dict_keys(['822766883'])
# problem in  dict_keys(['822769771'])
# problem in  dict_keys(['823317900'])
# problem in  dict_keys(['823318915'])
# problem in  dict_keys(['827908079'])
# problem in  dict_keys(['828730286'])
# problem in  dict_keys(['830598307'])
# problem in  dict_keys(['830629008'])
# problem in  dict_keys(['835150907'])
# problem in  dict_keys(['835150935'])
# problem in  dict_keys(['835151235'])
# problem in  dict_keys(['835151254'])
# problem in  dict_keys(['840126410'])
# problem in  dict_keys(['840324357'])
# problem in  dict_keys(['843097677'])
# problem in  dict_keys(['843565599'])
# problem in  dict_keys(['843577819'])
# problem in  dict_keys(['843583209'])
# problem in  dict_keys(['845514534'])
# problem in  dict_keys(['845515068'])
# problem in  dict_keys(['845515140'])
# problem in  dict_keys(['845631444'])
# problem in  dict_keys(['845642447'])
# problem in  dict_keys(['845648113'])
# problem in  dict_keys(['845648204'])
# problem in  dict_keys(['845656220'])
# problem in  dict_keys(['845661690'])
# problem in  dict_keys(['845662207'])
# problem in  dict_keys(['846530918'])
# problem in  dict_keys(['846635124'])
# problem in  dict_keys(['846635539'])
# problem in  dict_keys(['848480905'])
# problem in  dict_keys(['848480912'])
# problem in  dict_keys(['849838696'])
# problem in  dict_keys(['849847987'])
# problem in  dict_keys(['849933964'])
# problem in  dict_keys(['849934096'])
# problem in  dict_keys(['849934118'])
# problem in  dict_keys(['849934167'])
# CPU times: user 13.4 s, sys: 7.01 s, total: 20.4 s
# Wall time: 55.7 s

# %%
with open(content+".pkl", "wb") as file:
    pickle.dump(test_wiki, file)

# %% [markdown]
# ### reading the change object and clustering.

# %%
with open(content+".pkl", "rb") as file:
    wiki = pickle.load(file)

# %%
change_objects = []
wiki.revisions[:99].apply(lambda revision: change_objects.append(revision.change))
change_df = pd.concat(change_objects, sort=False, keys=wiki.revisions.index)

# %%
def get_word_vecs(tokens):
    in_vocab_tokens = set(tokens) & set(wiki_vec.vocab)
    if in_vocab_tokens:
        return wiki_vec[in_vocab_tokens].sum(axis=0, keepdims=True)
    else:
        return np.zeros((1, wiki_vec.vector_size))

# %%
# %%time
change_vecs_list = []
change_token_s = change_df["ins_tokens"] + change_df["del_tokens"]
change_token_s.apply(lambda token_set: change_vecs_list.append(get_word_vecs(token_set)))

change_matrix = np.concatenate(change_vecs_list, axis=0)

# %%
# %%time
neigh_vecs_list = []
neighbour_s = change_df['left_token'] + change_df['right_token']
neighbour_s.apply(lambda token_set: neigh_vecs_list.append(get_word_vecs(token_set)))

neighbour_matrix = np.concatenate(neigh_vecs_list, axis=0)

# %%
from_rev = wiki.revisions.iloc[0] 
to_rev = wiki.revisions.iloc[1]

# %%
# def neighbours(change, revision, wiki_vec, epsilon_size):
#     vocabs_pos = np.argwhere( revision.content["invocab"].values)
#     left = vocabs_pos[vocabs_pos < change["ins_starting_pos"]][:epsilon_size]
#     right = vocabs_pos[vocabs_pos > change["ins_end_pos"]][:epsilon_size]
#     neighbor_tokens = from_rev.content.str.values[np.r_[left,right]]
#     neighbour_vec = wiki_vec[neighbor_tokens].sum(axis=0)
#     combined_neighbour_vec = np.r_[left, right, neighbor_tokens, neighbour_vec]
#     return combined_neighbour_vec  
# added_pos = test_wiki.revisions[3317921].added_pos
# start_token_id = test_wiki.revisions[3317921].content["token_id"].values[added_pos[:,0]-1]
# end_token_id = test_wiki.revisions[3317921].content["token_id"].values[added_pos[:,1]+1]
# first_last_token = test_wiki.revisions[3317921].content["added"].values[[0,-1]]

# test_wiki.revisions[3317921].content["str"].values[np.s_[start_pos,end_pos[1:]]]

# test_wiki.revisions[3317921].content["str"].values[start_pos[0][0]:end_pos[1][0]+1]

# np.compress(test_wiki.revisions[3317921].content["removed"].values, test_wiki.revisions[3317921].content["str"].values)

# %% [markdown]
# ### Do clustering

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters= 30)
clusters = km.fit(neighbour_matrix)

# %%
cluster_s = pd.Series(clusters.labels_, index= change_df.index)
change_df["cluster"] = cluster_s
change_grouped = change_df.groupby("cluster")

# %%
change_grouped.size()

# %%
change_grouped.get_group(1)[["ins_tokens", "del_tokens", "left_neigh", "right_neigh"]].head(20)
